# %% [markdown]
# <a href="https://colab.research.google.com/github/Monunep/DPDPD/blob/main/DPDPD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random
import numpy as np
import copy

# ==============================================================================
#  CÁC HẰNG SỐ, DỮ LIỆU ĐẦU VÀO VÀ HÀM TIỆN ÍCH

# k cho các thuộc tính
NODE_TYPE = 0
TRUCK_DIST = 1
DRONE_DIST = 2
TRUCK_TIME = 3
DRONE_TIME = 4
A[i][j][k]
k

#  Node tp
TYPE_POT = 1
TYPE_HUB = 2
TYPE_CUSTOMER = 3

# (id, type, x, y, demand)
NODE_PROPERTIES = [
    {'id': 0, 'type': TYPE_POT,      'x': 50, 'y': 50, 'demand': 0},
    {'id': 1, 'type': TYPE_HUB,      'x': 20, 'y': 80, 'demand': 0},
    {'id': 2, 'type': TYPE_HUB,      'x': 80, 'y': 20, 'demand': 0},
    {'id': 3, 'type': TYPE_CUSTOMER, 'x': 15, 'y': 85, 'demand': 5},
    {'id': 4, 'type': TYPE_CUSTOMER, 'x': 95, 'y': 95, 'demand': 12},
    {'id': 5, 'type': TYPE_CUSTOMER, 'x': 50, 'y': 40, 'demand': 4},
    {'id': 6, 'type': TYPE_CUSTOMER, 'x': 85, 'y': 15, 'demand': 6} # Thêm một khách hàng
]

TRUCK_SPEED = 1.0
DRONE_SPEED = 10.0
DRONE_MAX_RANGE_DIST = 50
DRONE_CAPACITY = 10
TRUCK_CAPACITY = 50
DRONE_LAUNCH_TIME = 1
DRONE_LAND_TIME = 1
# random matrix
import random


def create_random_adjacency_matrix(num_nodes, num_hubs, num_customers,
                                   max_dist=100, truck_speed=1.0, drone_speed=2.0):
    """
    Tạo ra một ma trận kề 3D A[i][j][k] với các giá trị ngẫu nhiên.

    Args:
        num_nodes (int): Tổng số điểm (bao gồm kho).
        num_hubs (int): Số lượng trạm trung chuyển.
        num_customers (int): Số lượng khách hàng.
        max_dist (int): Khoảng cách tối đa có thể có giữa hai điểm.
        truck_speed (float): Tốc độ xe tải.
        drone_speed (float): Tốc độ drone.

    Returns:
        tuple: (Ma trận A, danh sách node_properties)
    """
    if 1 + num_hubs + num_customers != num_nodes:
        raise ValueError("Tổng số lượng các loại node khum khớp với num_nodes.")

    A = np.zeros((num_nodes, num_nodes, 5))
    node_properties = []

    #  ngẫu nhiên cho các đỉnh
    node_ids = list(range(1, num_nodes))
    random.shuffle(node_ids)

    # Node 0 là kho chính
    A[0, 0, NODE_TYPE] = TYPE_POT
    node_properties.append({'id': 0, 'type': TYPE_POT, 'demand': 0})

    # ngẫu nhiên các trạm trung chuyển
    for i in range(num_hubs):
        hub_id = node_ids.pop()
        A[hub_id, hub_id, NODE_TYPE] = TYPE_HUB
        node_properties.append({'id': hub_id, 'type': TYPE_HUB, 'demand': 0})

    # khách hàng
    for cust_id in node_ids:
        A[cust_id, cust_id, NODE_TYPE] = TYPE_CUSTOMER
        # Nhu cầa khách
        demand = random.randint(5, 20)
        node_properties.append({'id': cust_id, 'type': TYPE_CUSTOMER, 'demand': demand})

    # xếp node_properties theo ID
    node_properties.sort(key=lambda x: x['id'])

    # --- 2. Tạo thuộc tính ngẫu nhiên cho các cạnh ---
    for i in range(num_nodes):
        for j in range(num_nodes):
            if i == j:
                continue

            # Tạo khoảng cách ngẫu nhiên
            # Không đối xứng, A[i,j]
            disconnect = random.random()
            dist = random.uniform(5, max_dist)
            if(disconnect>0.1):
              A[i, j, TRUCK_DIST] = dist
              A[i, j, DRONE_DIST] = dist
              A[i, j, TRUCK_TIME] = dist / truck_speed
              A[i, j, DRONE_TIME] = dist / drone_speed
            else:
              A[i, j, TRUCK_DIST] = 1000000
              A[i, j, DRONE_DIST] = 1000000
              A[i, j, TRUCK_TIME] = 1000000 / truck_speed
              A[i, j, DRONE_TIME] = 1000000 / drone_speed

    return A, node_properties
# Do Thi Euclid
def create_adjacency_matrix(nodes, truck_speed, drone_speed):
    """
    Tạo ma trận kề 3D A[i][j][k] từ danh sách các node.
    """
    num_nodes = len(nodes)
    A = np.zeros((num_nodes, num_nodes, 5))

    for i in range(num_nodes):
        A[i, i, NODE_TYPE] = nodes[i]['type']
        for j in range(num_nodes):
            if i == j: continue
            p1 = nodes[i]
            p2 = nodes[j]
            dist = math.sqrt((p1['x'] - p2['x'])**2 + (p1['y'] - p2['y'])**2)
            A[i, j, TRUCK_DIST] = dist
            A[i, j, DRONE_DIST] = dist
            A[i, j, TRUCK_TIME] = dist / truck_speed
            A[i, j, DRONE_TIME] = dist / drone_speed
    return A
def print_matrix_details(A, node_properties):
    """
    In ra một báo cáo chi tiết, dễ đọc về nội dung của ma trận kề A.
    """
    num_nodes = A.shape[0]
    node_props_map = {node['id']: node for node in node_properties}

    # Anh xa tu ma so sang ten node
    node_type_map = {
        TYPE_POT: "Depot",
        TYPE_HUB: "Hub",
        TYPE_CUSTOMER: "Customer"
    }

    print("\n" + "="*60)
    print(f"      VISUALIZATION OF ADJACENCY MATRIX A ({num_nodes}x{num_nodes}x{A.shape[2]})")
    print("="*60)

    # duong cheo
    print("\n--- 1. Node Properties (Diagonal A[i,i,:]) ---")
    for i in range(num_nodes):
        node_type_code = A[i, i, NODE_TYPE]
        node_type_str = node_type_map.get(node_type_code, "Unknown")
        demand = node_props_map[i]['demand']
        print(f"Node {i}: Type = {node_type_str} (code={int(node_type_code)}), Demand = {demand}")

    # i khac j

    print("\n--- 2. Edge Properties (Off-diagonal A[i,j,:]) ---")
    for i in range(num_nodes):
        for j in range(num_nodes):
            if i == j:
                continue

            print(f"\n--- Edge {i} -> {j} ---")

            # matrix info
            truck_dist = A[i, j, TRUCK_DIST]
            truck_time = A[i, j, TRUCK_TIME]
            drone_dist = A[i, j, DRONE_DIST]
            drone_time = A[i, j, DRONE_TIME]

            print(f"  - Truck Info: (Distance: {truck_dist:.2f}, Time: {truck_time:.2f})")
            print(f"  - Drone Info: (Distance: {drone_dist:.2f}, Time: {drone_time:.2f})")

    print("\n" + "="*60)
    print("           END OF MATRIX VISUALIZATION")
    print("="*60 + "\n")

# ==============================================================================
# 2: INITIAL HEURISTIC
class MatrixSolver:
    def __init__(self, A, node_properties):
        self.A = A
        self.node_props = {node['id']: node for node in node_properties}
        self.num_nodes = A.shape[0]

    def initialize_solution(self):
        hub_ids = [i for i in range(self.num_nodes) if self.A[i, i, NODE_TYPE] == TYPE_HUB]
        customer_ids = [i for i in range(self.num_nodes) if self.A[i, i, NODE_TYPE] == TYPE_CUSTOMER]

        hub_drone_assignments = {hid: [] for hid in hub_ids}
        hub_demands = {hid: 0 for hid in hub_ids}
        unserved_customers = list(customer_ids)

        for req_id in list(unserved_customers):
            best_hub = min(hub_ids, key=lambda hid: self.A[req_id, hid, DRONE_DIST])
            min_dist = self.A[req_id, best_hub, DRONE_DIST]
            if min_dist * 2 <= DRONE_MAX_RANGE_DIST:
                hub_drone_assignments[best_hub].append(req_id)
                hub_demands[best_hub] += self.node_props[req_id]['demand']
                unserved_customers.remove(req_id)

        points_for_truck_ids = unserved_customers + [hid for hid in hub_ids if hub_demands[hid] > 0]
        truck_route = []
        current_loc = 0

        total_demand_for_truck = sum(self.node_props[pid]['demand'] for pid in unserved_customers) + sum(hub_demands.values())
        if total_demand_for_truck > TRUCK_CAPACITY:
            print("  - ERROR: Initial demand exceeds truck capacity. Solution may be infeasible.")

        while points_for_truck_ids:
            next_point_id = min(points_for_truck_ids, key=lambda pid: self.A[current_loc, pid, TRUCK_DIST])
            truck_route.append(next_point_id)
            current_loc = next_point_id
            points_for_truck_ids.remove(next_point_id)

        truck_launched_assignments = []

        return {
            'truck_route': truck_route,
            'hub_drone_assignments': hub_drone_assignments,
            'truck_launched_assignments': truck_launched_assignments,
            'unserved_requests': unserved_customers # Sẽ trống nếu tải trọng đủ
        }


#  3: SIÊU THUẬT TOÁN ALNS
class ALNSSolver:
    def __init__(self, A, node_properties, iterations=500, penalty_unserved=1000):
        self.A = A
        self.node_props = node_properties
        self.iterations = iterations
        self.penalty_unserved = penalty_unserved
        self.destroy_operators = [self.random_removal]
        self.repair_operators = [self.greedy_insertion]
        self.op_weights = {'destroy': [1] * len(self.destroy_operators), 'repair': [1] * len(self.repair_operators)}
        self.op_scores = {'destroy': [0]*len(self.destroy_operators), 'repair': [0]*len(self.repair_operators)}
        self.op_counts = {'destroy': [0]*len(self.destroy_operators), 'repair': [0]*len(self.repair_operators)}
        self.reaction_factor = 0.5
        self.start_temperature = 500
        self.end_temperature = 1
        self.cooling_rate = 0.995

    def solve(self, initial_solution):
        current_solution = copy.deepcopy(initial_solution)
        best_solution = copy.deepcopy(initial_solution)
        current_cost = self.calculate_cost(current_solution)
        best_cost = current_cost
        temperature = self.start_temperature
        print(f"Initial Cost: {best_cost:.2f}")

        for i in range(self.iterations):
            destroy_op_idx, destroy_op = self._select_operator('destroy')
            repair_op_idx, repair_op = self._select_operator('repair')

            partial_solution, removed_requests = destroy_op(current_solution)
            new_solution = repair_op(partial_solution, removed_requests)
            new_cost = self.calculate_cost(new_solution)

            score = 0
            if new_cost < best_cost:
                best_solution = copy.deepcopy(new_solution)
                best_cost = new_cost
                current_solution = copy.deepcopy(new_solution)
                current_cost = new_cost
                score = 3
                print(f"Iteration {i+1}/{self.iterations} | New Best Cost: {best_cost:.2f} (T={temperature:.2f})")
            elif new_cost < current_cost:
                current_solution = copy.deepcopy(new_solution)
                current_cost = new_cost
                score = 2
            elif random.random() < math.exp((current_cost - new_cost) / temperature):
                current_solution = copy.deepcopy(new_solution)
                current_cost = new_cost
                score = 1

            self._update_weights(destroy_op_idx, repair_op_idx, score)
            temperature = max(self.end_temperature, temperature * self.cooling_rate)

        print(f"\nFinished. Final Best Cost: {best_cost:.2f}")
        return best_solution

    def calculate_cost(self, solution):
        if not solution: return float('inf')
        total_dist = 0
        route = [0] + solution['truck_route'] + [0]
        for i in range(len(route) - 1):
            total_dist += self.A[route[i], route[i+1], TRUCK_DIST]
        for hub_id, reqs in solution['hub_drone_assignments'].items():
            for req_id in reqs:
                total_dist += 2 * self.A[hub_id, req_id, DRONE_DIST]
        for assign in solution['truck_launched_assignments']:
            total_dist += self.A[assign['launch'], assign['req_id'], DRONE_DIST] + self.A[assign['req_id'], assign['rendezvous'], DRONE_DIST]
        penalty = len(solution['unserved_requests']) * self.penalty_unserved
        return total_dist + penalty
# PHẦN THAY THẾ TRONG LỚP ALNSSolver

    # --- Các toán tử Phá hủy (Sửa lỗi nhỏ để đảm bảo không có unserved trùng lặp) ---
    def random_removal(self, solution, percentage=0.2):
        sol = copy.deepcopy(solution)
        served_customers = []

        # Lấy danh sách khách hàng đang được phục vụ
        truck_customers = {r for r in sol['truck_route'] if self.A[r,r,NODE_TYPE] == TYPE_CUSTOMER}
        hub_customers = {r for r_list in sol['hub_drone_assignments'].values() for r in r_list}
        truck_drone_customers = {a['req_id'] for a in sol['truck_launched_assignments']}

        served_customers = list(truck_customers | hub_customers | truck_drone_customers)

        if not served_customers:
            return sol, []

        num_to_remove = max(1, int(len(served_customers) * percentage))
        requests_to_remove = random.sample(served_customers, num_to_remove)

        # xay giải pháp bị phá hủy
        sol['truck_route'] = [r for r in sol['truck_route'] if r not in requests_to_remove]
        for hub_id in sol['hub_drone_assignments']:
            sol['hub_drone_assignments'][hub_id] = [r for r in sol['hub_drone_assignments'][hub_id] if r not in requests_to_remove]
        sol['truck_launched_assignments'] = [a for a in sol['truck_launched_assignments'] if a['req_id'] not in requests_to_remove]

        # dảm bảo danh sách unserved là duy nhất
        current_unserved = set(sol['unserved_requests'])
        current_unserved.update(requests_to_remove)
        sol['unserved_requests'] = list(current_unserved)

        return sol, requests_to_remove

    # greedy
    def greedy_insertion(self, partial_solution, requests_to_insert):
        """
        Chèn lại các khách hàng một cách an toàn và nhất quán.
        Đây là một heuristic tham lam đơn giản: nó chèn từng khách hàng một
        vào vị trí tốt nhất tại thời điểm đó.
        """
        sol = copy.deepcopy(partial_solution)

        # lặp qua các khách chèn lại
        for req_id in requests_to_insert:
            best_move = {'cost': float('inf'), 'solution': None}


            # 1. Thử chèn vào tuyến xe tải ở mọi vị trí
            for i in range(len(sol['truck_route']) + 1):
                temp_sol = copy.deepcopy(sol)
                temp_sol['truck_route'].insert(i, req_id)
                # Quan trọng: Xóa khỏi unserved trong bản sao tạm thời để tính chi phí đúng
                if req_id in temp_sol['unserved_requests']:
                    temp_sol['unserved_requests'].remove(req_id)

                cost = self.calculate_cost(temp_sol)
                if cost < best_move['cost']:
                    best_move['cost'] = cost
                    best_move['solution'] = temp_sol

            # 2. Thử gán cho mỗi trạm trung chuyển
            for hub_id in sol['hub_drone_assignments']:
                # (Trong hệ thống đầy đủ, cần kiểm tra ràng buộc tầm bay/tải trọng ở đây)
                temp_sol = copy.deepcopy(sol)
                temp_sol['hub_drone_assignments'][hub_id].append(req_id)
                if req_id in temp_sol['unserved_requests']:
                    temp_sol['unserved_requests'].remove(req_id)

                cost = self.calculate_cost(temp_sol)
                if cost < best_move['cost']:
                    best_move['cost'] = cost
                    best_move['solution'] = temp_sol

            # (Logic cho truck-launched drone  (idk hehe)

            #  nước đi tốt nhất cho req_id
            if best_move['solution']:
                sol = best_move['solution']

        return sol

    def _select_operator(self, op_type):
        weights = self.op_weights[op_type]
        total_weight = sum(weights)
        rand_val = random.uniform(0, total_weight)
        cumulative_weight = 0
        for i, weight in enumerate(weights):
            cumulative_weight += weight
            if rand_val <= cumulative_weight:
                return (i, self.destroy_operators[i]) if op_type == 'destroy' else (i, self.repair_operators[i])

    def _update_weights(self, destroy_idx, repair_idx, score):
        if score > 0: # Chỉ cập nhật nếu có sự thay đổi
            self.op_scores['destroy'][destroy_idx] += score
            self.op_scores['repair'][repair_idx] += score
            self.op_counts['destroy'][destroy_idx] += 1
            self.op_counts['repair'][repair_idx] += 1

            # Cập nhật định kỳ để tránh chia cho 0 và làm mới trọng số
            if sum(self.op_counts['destroy']) % 50 == 0:
                for op_type in ['destroy', 'repair']:
                    for i in range(len(self.op_weights[op_type])):
                        count = self.op_counts[op_type][i]
                        avg_score = self.op_scores[op_type][i] / count if count > 0 else 0
                        self.op_weights[op_type][i] = (1 - self.reaction_factor) * self.op_weights[op_type][i] + self.reaction_factor * avg_score

# 4: CHƯƠNG TRÌNH CHÍNH
if __name__ == "__main__":
    # input
    print("--- STEP 1: Creating Adjacency Matrix A ---")
    #euclid
    # A = create_adjacency_matrix(NODE_PROPERTIES, TRUCK_SPEED, DRONE_SPEED)
    print("--- STEP 1: Creating RANDOM Adjacency Matrix A ---")

    NUM_NODES = 50       # 1 kho + 20 trạm + 29 khách
    NUM_HUBS = 20
    NUM_CUSTOMERS = 29

    A, RANDOM_NODE_PROPERTIES = create_random_adjacency_matrix(
        num_nodes=NUM_NODES,
        num_hubs=NUM_HUBS,
        num_customers=NUM_CUSTOMERS
    )
    # GỌI HÀM IN
    print_matrix_details(A, RANDOM_NODE_PROPERTIES)
    #   heuristic ban đầu
    print("\n--- STEP 2: Creating Initial Heuristic Solution ---")
    initial_solver = MatrixSolver(A, RANDOM_NODE_PROPERTIES)
    initial_solution = initial_solver.initialize_solution()

    if initial_solution:
        #  Chạy ALNS để cải tiến giải pháp
        print("\n--- STEP 3: Running ALNS Metaheuristic ---")
        alns_solver = ALNSSolver(A, RANDOM_NODE_PROPERTIES, iterations=500, penalty_unserved=1000)
        final_solution = alns_solver.solve(initial_solution)

        # Final SOl
        print("\n" + "="*40)
        print("      FINAL SOLUTION SUMMARY")
        print("="*40)
        print("\n1. Truck Route:")
        if final_solution['truck_route']:
            path_str = ' -> '.join(map(str, final_solution['truck_route']))
            print(f"  - 0 -> {path_str} -> 0")
        else:
            print("  - Not used.")

        print("\n2. Hub-based Drone Deliveries:")
        for hub_id, reqs in final_solution['hub_drone_assignments'].items():
            if reqs:
                print(f"  - Hub {hub_id} serves: {reqs}")

        print("\n3. Truck-launched Drone Deliveries:")
        if final_solution['truck_launched_assignments']:
            for assign in final_solution['truck_launched_assignments']:
                print(f"  - Customer {assign['req_id']} from segment {assign['launch']}->{assign['rendezvous']}")
        else:
            print("  - None.")

        print("\n4. Unserved Requests:")
        if final_solution['unserved_requests']:
            print(f"  - {final_solution['unserved_requests']}")
        else:
            print("  - All requests served.")
# Out:
# Streaming output truncated to the last 5000 lines.
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 24 -> 39 ---
#   - Truck Info: (Distance: 62.90, Time: 62.90)
#   - Drone Info: (Distance: 62.90, Time: 31.45)
#
# --- Edge 24 -> 40 ---
#   - Truck Info: (Distance: 95.45, Time: 95.45)
#   - Drone Info: (Distance: 95.45, Time: 47.73)
#
# --- Edge 24 -> 41 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 24 -> 42 ---
#   - Truck Info: (Distance: 71.61, Time: 71.61)
#   - Drone Info: (Distance: 71.61, Time: 35.80)
#
# --- Edge 24 -> 43 ---
#   - Truck Info: (Distance: 40.90, Time: 40.90)
#   - Drone Info: (Distance: 40.90, Time: 20.45)
#
# --- Edge 24 -> 44 ---
#   - Truck Info: (Distance: 89.96, Time: 89.96)
#   - Drone Info: (Distance: 89.96, Time: 44.98)
#
# --- Edge 24 -> 45 ---
#   - Truck Info: (Distance: 5.67, Time: 5.67)
#   - Drone Info: (Distance: 5.67, Time: 2.84)
#
# --- Edge 24 -> 46 ---
#   - Truck Info: (Distance: 37.31, Time: 37.31)
#   - Drone Info: (Distance: 37.31, Time: 18.65)
#
# --- Edge 24 -> 47 ---
#   - Truck Info: (Distance: 60.37, Time: 60.37)
#   - Drone Info: (Distance: 60.37, Time: 30.18)
#
# --- Edge 24 -> 48 ---
#   - Truck Info: (Distance: 58.50, Time: 58.50)
#   - Drone Info: (Distance: 58.50, Time: 29.25)
#
# --- Edge 24 -> 49 ---
#   - Truck Info: (Distance: 82.47, Time: 82.47)
#   - Drone Info: (Distance: 82.47, Time: 41.24)
#
# --- Edge 25 -> 0 ---
#   - Truck Info: (Distance: 20.07, Time: 20.07)
#   - Drone Info: (Distance: 20.07, Time: 10.03)
#
# --- Edge 25 -> 1 ---
#   - Truck Info: (Distance: 93.00, Time: 93.00)
#   - Drone Info: (Distance: 93.00, Time: 46.50)
#
# --- Edge 25 -> 2 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 25 -> 3 ---
#   - Truck Info: (Distance: 70.23, Time: 70.23)
#   - Drone Info: (Distance: 70.23, Time: 35.11)
#
# --- Edge 25 -> 4 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 25 -> 5 ---
#   - Truck Info: (Distance: 76.53, Time: 76.53)
#   - Drone Info: (Distance: 76.53, Time: 38.27)
#
# --- Edge 25 -> 6 ---
#   - Truck Info: (Distance: 50.14, Time: 50.14)
#   - Drone Info: (Distance: 50.14, Time: 25.07)
#
# --- Edge 25 -> 7 ---
#   - Truck Info: (Distance: 22.59, Time: 22.59)
#   - Drone Info: (Distance: 22.59, Time: 11.30)
#
# --- Edge 25 -> 8 ---
#   - Truck Info: (Distance: 18.96, Time: 18.96)
#   - Drone Info: (Distance: 18.96, Time: 9.48)
#
# --- Edge 25 -> 9 ---
#   - Truck Info: (Distance: 73.35, Time: 73.35)
#   - Drone Info: (Distance: 73.35, Time: 36.67)
#
# --- Edge 25 -> 10 ---
#   - Truck Info: (Distance: 34.17, Time: 34.17)
#   - Drone Info: (Distance: 34.17, Time: 17.09)
#
# --- Edge 25 -> 11 ---
#   - Truck Info: (Distance: 10.01, Time: 10.01)
#   - Drone Info: (Distance: 10.01, Time: 5.00)
#
# --- Edge 25 -> 12 ---
#   - Truck Info: (Distance: 7.88, Time: 7.88)
#   - Drone Info: (Distance: 7.88, Time: 3.94)
#
# --- Edge 25 -> 13 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 25 -> 14 ---
#   - Truck Info: (Distance: 76.72, Time: 76.72)
#   - Drone Info: (Distance: 76.72, Time: 38.36)
#
# --- Edge 25 -> 15 ---
#   - Truck Info: (Distance: 18.01, Time: 18.01)
#   - Drone Info: (Distance: 18.01, Time: 9.00)
#
# --- Edge 25 -> 16 ---
#   - Truck Info: (Distance: 89.71, Time: 89.71)
#   - Drone Info: (Distance: 89.71, Time: 44.86)
#
# --- Edge 25 -> 17 ---
#   - Truck Info: (Distance: 97.59, Time: 97.59)
#   - Drone Info: (Distance: 97.59, Time: 48.80)
#
# --- Edge 25 -> 18 ---
#   - Truck Info: (Distance: 23.05, Time: 23.05)
#   - Drone Info: (Distance: 23.05, Time: 11.52)
#
# --- Edge 25 -> 19 ---
#   - Truck Info: (Distance: 21.82, Time: 21.82)
#   - Drone Info: (Distance: 21.82, Time: 10.91)
#
# --- Edge 25 -> 20 ---
#   - Truck Info: (Distance: 36.87, Time: 36.87)
#   - Drone Info: (Distance: 36.87, Time: 18.43)
#
# --- Edge 25 -> 21 ---
#   - Truck Info: (Distance: 24.51, Time: 24.51)
#   - Drone Info: (Distance: 24.51, Time: 12.25)
#
# --- Edge 25 -> 22 ---
#   - Truck Info: (Distance: 91.90, Time: 91.90)
#   - Drone Info: (Distance: 91.90, Time: 45.95)
#
# --- Edge 25 -> 23 ---
#   - Truck Info: (Distance: 78.48, Time: 78.48)
#   - Drone Info: (Distance: 78.48, Time: 39.24)
#
# --- Edge 25 -> 24 ---
#   - Truck Info: (Distance: 43.73, Time: 43.73)
#   - Drone Info: (Distance: 43.73, Time: 21.87)
#
# --- Edge 25 -> 26 ---
#   - Truck Info: (Distance: 9.38, Time: 9.38)
#   - Drone Info: (Distance: 9.38, Time: 4.69)
#
# --- Edge 25 -> 27 ---
#   - Truck Info: (Distance: 10.99, Time: 10.99)
#   - Drone Info: (Distance: 10.99, Time: 5.50)
#
# --- Edge 25 -> 28 ---
#   - Truck Info: (Distance: 95.06, Time: 95.06)
#   - Drone Info: (Distance: 95.06, Time: 47.53)
#
# --- Edge 25 -> 29 ---
#   - Truck Info: (Distance: 68.43, Time: 68.43)
#   - Drone Info: (Distance: 68.43, Time: 34.21)
#
# --- Edge 25 -> 30 ---
#   - Truck Info: (Distance: 51.39, Time: 51.39)
#   - Drone Info: (Distance: 51.39, Time: 25.70)
#
# --- Edge 25 -> 31 ---
#   - Truck Info: (Distance: 97.45, Time: 97.45)
#   - Drone Info: (Distance: 97.45, Time: 48.73)
#
# --- Edge 25 -> 32 ---
#   - Truck Info: (Distance: 98.52, Time: 98.52)
#   - Drone Info: (Distance: 98.52, Time: 49.26)
#
# --- Edge 25 -> 33 ---
#   - Truck Info: (Distance: 82.30, Time: 82.30)
#   - Drone Info: (Distance: 82.30, Time: 41.15)
#
# --- Edge 25 -> 34 ---
#   - Truck Info: (Distance: 99.51, Time: 99.51)
#   - Drone Info: (Distance: 99.51, Time: 49.75)
#
# --- Edge 25 -> 35 ---
#   - Truck Info: (Distance: 38.27, Time: 38.27)
#   - Drone Info: (Distance: 38.27, Time: 19.13)
#
# --- Edge 25 -> 36 ---
#   - Truck Info: (Distance: 41.85, Time: 41.85)
#   - Drone Info: (Distance: 41.85, Time: 20.93)
#
# --- Edge 25 -> 37 ---
#   - Truck Info: (Distance: 90.33, Time: 90.33)
#   - Drone Info: (Distance: 90.33, Time: 45.17)
#
# --- Edge 25 -> 38 ---
#   - Truck Info: (Distance: 31.67, Time: 31.67)
#   - Drone Info: (Distance: 31.67, Time: 15.84)
#
# --- Edge 25 -> 39 ---
#   - Truck Info: (Distance: 86.97, Time: 86.97)
#   - Drone Info: (Distance: 86.97, Time: 43.48)
#
# --- Edge 25 -> 40 ---
#   - Truck Info: (Distance: 43.59, Time: 43.59)
#   - Drone Info: (Distance: 43.59, Time: 21.80)
#
# --- Edge 25 -> 41 ---
#   - Truck Info: (Distance: 74.97, Time: 74.97)
#   - Drone Info: (Distance: 74.97, Time: 37.48)
#
# --- Edge 25 -> 42 ---
#   - Truck Info: (Distance: 45.47, Time: 45.47)
#   - Drone Info: (Distance: 45.47, Time: 22.74)
#
# --- Edge 25 -> 43 ---
#   - Truck Info: (Distance: 30.92, Time: 30.92)
#   - Drone Info: (Distance: 30.92, Time: 15.46)
#
# --- Edge 25 -> 44 ---
#   - Truck Info: (Distance: 53.10, Time: 53.10)
#   - Drone Info: (Distance: 53.10, Time: 26.55)
#
# --- Edge 25 -> 45 ---
#   - Truck Info: (Distance: 90.95, Time: 90.95)
#   - Drone Info: (Distance: 90.95, Time: 45.48)
#
# --- Edge 25 -> 46 ---
#   - Truck Info: (Distance: 94.44, Time: 94.44)
#   - Drone Info: (Distance: 94.44, Time: 47.22)
#
# --- Edge 25 -> 47 ---
#   - Truck Info: (Distance: 92.84, Time: 92.84)
#   - Drone Info: (Distance: 92.84, Time: 46.42)
#
# --- Edge 25 -> 48 ---
#   - Truck Info: (Distance: 59.36, Time: 59.36)
#   - Drone Info: (Distance: 59.36, Time: 29.68)
#
# --- Edge 25 -> 49 ---
#   - Truck Info: (Distance: 8.68, Time: 8.68)
#   - Drone Info: (Distance: 8.68, Time: 4.34)
#
# --- Edge 26 -> 0 ---
#   - Truck Info: (Distance: 19.51, Time: 19.51)
#   - Drone Info: (Distance: 19.51, Time: 9.75)
#
# --- Edge 26 -> 1 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 26 -> 2 ---
#   - Truck Info: (Distance: 30.29, Time: 30.29)
#   - Drone Info: (Distance: 30.29, Time: 15.14)
#
# --- Edge 26 -> 3 ---
#   - Truck Info: (Distance: 29.47, Time: 29.47)
#   - Drone Info: (Distance: 29.47, Time: 14.74)
#
# --- Edge 26 -> 4 ---
#   - Truck Info: (Distance: 41.65, Time: 41.65)
#   - Drone Info: (Distance: 41.65, Time: 20.82)
#
# --- Edge 26 -> 5 ---
#   - Truck Info: (Distance: 70.09, Time: 70.09)
#   - Drone Info: (Distance: 70.09, Time: 35.05)
#
# --- Edge 26 -> 6 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 26 -> 7 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 26 -> 8 ---
#   - Truck Info: (Distance: 28.21, Time: 28.21)
#   - Drone Info: (Distance: 28.21, Time: 14.10)
#
# --- Edge 26 -> 9 ---
#   - Truck Info: (Distance: 15.96, Time: 15.96)
#   - Drone Info: (Distance: 15.96, Time: 7.98)
#
# --- Edge 26 -> 10 ---
#   - Truck Info: (Distance: 15.18, Time: 15.18)
#   - Drone Info: (Distance: 15.18, Time: 7.59)
#
# --- Edge 26 -> 11 ---
#   - Truck Info: (Distance: 63.79, Time: 63.79)
#   - Drone Info: (Distance: 63.79, Time: 31.90)
#
# --- Edge 26 -> 12 ---
#   - Truck Info: (Distance: 81.08, Time: 81.08)
#   - Drone Info: (Distance: 81.08, Time: 40.54)
#
# --- Edge 26 -> 13 ---
#   - Truck Info: (Distance: 83.97, Time: 83.97)
#   - Drone Info: (Distance: 83.97, Time: 41.98)
#
# --- Edge 26 -> 14 ---
#   - Truck Info: (Distance: 46.95, Time: 46.95)
#   - Drone Info: (Distance: 46.95, Time: 23.48)
#
# --- Edge 26 -> 15 ---
#   - Truck Info: (Distance: 25.46, Time: 25.46)
#   - Drone Info: (Distance: 25.46, Time: 12.73)
#
# --- Edge 26 -> 16 ---
#   - Truck Info: (Distance: 24.99, Time: 24.99)
#   - Drone Info: (Distance: 24.99, Time: 12.49)
#
# --- Edge 26 -> 17 ---
#   - Truck Info: (Distance: 14.32, Time: 14.32)
#   - Drone Info: (Distance: 14.32, Time: 7.16)
#
# --- Edge 26 -> 18 ---
#   - Truck Info: (Distance: 82.17, Time: 82.17)
#   - Drone Info: (Distance: 82.17, Time: 41.08)
#
# --- Edge 26 -> 19 ---
#   - Truck Info: (Distance: 13.73, Time: 13.73)
#   - Drone Info: (Distance: 13.73, Time: 6.87)
#
# --- Edge 26 -> 20 ---
#   - Truck Info: (Distance: 16.79, Time: 16.79)
#   - Drone Info: (Distance: 16.79, Time: 8.39)
#
# --- Edge 26 -> 21 ---
#   - Truck Info: (Distance: 38.43, Time: 38.43)
#   - Drone Info: (Distance: 38.43, Time: 19.22)
#
# --- Edge 26 -> 22 ---
#   - Truck Info: (Distance: 34.85, Time: 34.85)
#   - Drone Info: (Distance: 34.85, Time: 17.42)
#
# --- Edge 26 -> 23 ---
#   - Truck Info: (Distance: 58.37, Time: 58.37)
#   - Drone Info: (Distance: 58.37, Time: 29.18)
#
# --- Edge 26 -> 24 ---
#   - Truck Info: (Distance: 17.56, Time: 17.56)
#   - Drone Info: (Distance: 17.56, Time: 8.78)
#
# --- Edge 26 -> 25 ---
#   - Truck Info: (Distance: 85.64, Time: 85.64)
#   - Drone Info: (Distance: 85.64, Time: 42.82)
#
# --- Edge 26 -> 27 ---
#   - Truck Info: (Distance: 93.39, Time: 93.39)
#   - Drone Info: (Distance: 93.39, Time: 46.70)
#
# --- Edge 26 -> 28 ---
#   - Truck Info: (Distance: 92.96, Time: 92.96)
#   - Drone Info: (Distance: 92.96, Time: 46.48)
#
# --- Edge 26 -> 29 ---
#   - Truck Info: (Distance: 69.44, Time: 69.44)
#   - Drone Info: (Distance: 69.44, Time: 34.72)
#
# --- Edge 26 -> 30 ---
#   - Truck Info: (Distance: 81.95, Time: 81.95)
#   - Drone Info: (Distance: 81.95, Time: 40.97)
#
# --- Edge 26 -> 31 ---
#   - Truck Info: (Distance: 85.91, Time: 85.91)
#   - Drone Info: (Distance: 85.91, Time: 42.96)
#
# --- Edge 26 -> 32 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 26 -> 33 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 26 -> 34 ---
#   - Truck Info: (Distance: 8.65, Time: 8.65)
#   - Drone Info: (Distance: 8.65, Time: 4.32)
#
# --- Edge 26 -> 35 ---
#   - Truck Info: (Distance: 40.65, Time: 40.65)
#   - Drone Info: (Distance: 40.65, Time: 20.32)
#
# --- Edge 26 -> 36 ---
#   - Truck Info: (Distance: 78.51, Time: 78.51)
#   - Drone Info: (Distance: 78.51, Time: 39.26)
#
# --- Edge 26 -> 37 ---
#   - Truck Info: (Distance: 52.40, Time: 52.40)
#   - Drone Info: (Distance: 52.40, Time: 26.20)
#
# --- Edge 26 -> 38 ---
#   - Truck Info: (Distance: 15.61, Time: 15.61)
#   - Drone Info: (Distance: 15.61, Time: 7.80)
#
# --- Edge 26 -> 39 ---
#   - Truck Info: (Distance: 42.63, Time: 42.63)
#   - Drone Info: (Distance: 42.63, Time: 21.32)
#
# --- Edge 26 -> 40 ---
#   - Truck Info: (Distance: 38.31, Time: 38.31)
#   - Drone Info: (Distance: 38.31, Time: 19.15)
#
# --- Edge 26 -> 41 ---
#   - Truck Info: (Distance: 19.14, Time: 19.14)
#   - Drone Info: (Distance: 19.14, Time: 9.57)
#
# --- Edge 26 -> 42 ---
#   - Truck Info: (Distance: 13.22, Time: 13.22)
#   - Drone Info: (Distance: 13.22, Time: 6.61)
#
# --- Edge 26 -> 43 ---
#   - Truck Info: (Distance: 38.95, Time: 38.95)
#   - Drone Info: (Distance: 38.95, Time: 19.48)
#
# --- Edge 26 -> 44 ---
#   - Truck Info: (Distance: 9.22, Time: 9.22)
#   - Drone Info: (Distance: 9.22, Time: 4.61)
#
# --- Edge 26 -> 45 ---
#   - Truck Info: (Distance: 97.82, Time: 97.82)
#   - Drone Info: (Distance: 97.82, Time: 48.91)
#
# --- Edge 26 -> 46 ---
#   - Truck Info: (Distance: 83.86, Time: 83.86)
#   - Drone Info: (Distance: 83.86, Time: 41.93)
#
# --- Edge 26 -> 47 ---
#   - Truck Info: (Distance: 88.03, Time: 88.03)
#   - Drone Info: (Distance: 88.03, Time: 44.01)
#
# --- Edge 26 -> 48 ---
#   - Truck Info: (Distance: 94.93, Time: 94.93)
#   - Drone Info: (Distance: 94.93, Time: 47.47)
#
# --- Edge 26 -> 49 ---
#   - Truck Info: (Distance: 35.30, Time: 35.30)
#   - Drone Info: (Distance: 35.30, Time: 17.65)
#
# --- Edge 27 -> 0 ---
#   - Truck Info: (Distance: 56.95, Time: 56.95)
#   - Drone Info: (Distance: 56.95, Time: 28.48)
#
# --- Edge 27 -> 1 ---
#   - Truck Info: (Distance: 43.20, Time: 43.20)
#   - Drone Info: (Distance: 43.20, Time: 21.60)
#
# --- Edge 27 -> 2 ---
#   - Truck Info: (Distance: 17.57, Time: 17.57)
#   - Drone Info: (Distance: 17.57, Time: 8.78)
#
# --- Edge 27 -> 3 ---
#   - Truck Info: (Distance: 76.79, Time: 76.79)
#   - Drone Info: (Distance: 76.79, Time: 38.39)
#
# --- Edge 27 -> 4 ---
#   - Truck Info: (Distance: 30.87, Time: 30.87)
#   - Drone Info: (Distance: 30.87, Time: 15.43)
#
# --- Edge 27 -> 5 ---
#   - Truck Info: (Distance: 54.67, Time: 54.67)
#   - Drone Info: (Distance: 54.67, Time: 27.34)
#
# --- Edge 27 -> 6 ---
#   - Truck Info: (Distance: 23.01, Time: 23.01)
#   - Drone Info: (Distance: 23.01, Time: 11.51)
#
# --- Edge 27 -> 7 ---
#   - Truck Info: (Distance: 35.68, Time: 35.68)
#   - Drone Info: (Distance: 35.68, Time: 17.84)
#
# --- Edge 27 -> 8 ---
#   - Truck Info: (Distance: 26.03, Time: 26.03)
#   - Drone Info: (Distance: 26.03, Time: 13.02)
#
# --- Edge 27 -> 9 ---
#   - Truck Info: (Distance: 79.32, Time: 79.32)
#   - Drone Info: (Distance: 79.32, Time: 39.66)
#
# --- Edge 27 -> 10 ---
#   - Truck Info: (Distance: 67.98, Time: 67.98)
#   - Drone Info: (Distance: 67.98, Time: 33.99)
#
# --- Edge 27 -> 11 ---
#   - Truck Info: (Distance: 56.11, Time: 56.11)
#   - Drone Info: (Distance: 56.11, Time: 28.06)
#
# --- Edge 27 -> 12 ---
#   - Truck Info: (Distance: 22.68, Time: 22.68)
#   - Drone Info: (Distance: 22.68, Time: 11.34)
#
# --- Edge 27 -> 13 ---
#   - Truck Info: (Distance: 30.30, Time: 30.30)
#   - Drone Info: (Distance: 30.30, Time: 15.15)
#
# --- Edge 27 -> 14 ---
#   - Truck Info: (Distance: 88.89, Time: 88.89)
#   - Drone Info: (Distance: 88.89, Time: 44.45)
#
# --- Edge 27 -> 15 ---
#   - Truck Info: (Distance: 15.41, Time: 15.41)
#   - Drone Info: (Distance: 15.41, Time: 7.71)
#
# --- Edge 27 -> 16 ---
#   - Truck Info: (Distance: 12.17, Time: 12.17)
#   - Drone Info: (Distance: 12.17, Time: 6.08)
#
# --- Edge 27 -> 17 ---
#   - Truck Info: (Distance: 81.16, Time: 81.16)
#   - Drone Info: (Distance: 81.16, Time: 40.58)
#
# --- Edge 27 -> 18 ---
#   - Truck Info: (Distance: 99.38, Time: 99.38)
#   - Drone Info: (Distance: 99.38, Time: 49.69)
#
# --- Edge 27 -> 19 ---
#   - Truck Info: (Distance: 34.32, Time: 34.32)
#   - Drone Info: (Distance: 34.32, Time: 17.16)
#
# --- Edge 27 -> 20 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 27 -> 21 ---
#   - Truck Info: (Distance: 64.67, Time: 64.67)
#   - Drone Info: (Distance: 64.67, Time: 32.34)
#
# --- Edge 27 -> 22 ---
#   - Truck Info: (Distance: 37.91, Time: 37.91)
#   - Drone Info: (Distance: 37.91, Time: 18.95)
#
# --- Edge 27 -> 23 ---
#   - Truck Info: (Distance: 19.35, Time: 19.35)
#   - Drone Info: (Distance: 19.35, Time: 9.67)
#
# --- Edge 27 -> 24 ---
#   - Truck Info: (Distance: 36.81, Time: 36.81)
#   - Drone Info: (Distance: 36.81, Time: 18.41)
#
# --- Edge 27 -> 25 ---
#   - Truck Info: (Distance: 56.09, Time: 56.09)
#   - Drone Info: (Distance: 56.09, Time: 28.04)
#
# --- Edge 27 -> 26 ---
#   - Truck Info: (Distance: 13.29, Time: 13.29)
#   - Drone Info: (Distance: 13.29, Time: 6.64)
#
# --- Edge 27 -> 28 ---
#   - Truck Info: (Distance: 53.72, Time: 53.72)
#   - Drone Info: (Distance: 53.72, Time: 26.86)
#
# --- Edge 27 -> 29 ---
#   - Truck Info: (Distance: 13.28, Time: 13.28)
#   - Drone Info: (Distance: 13.28, Time: 6.64)
#
# --- Edge 27 -> 30 ---
#   - Truck Info: (Distance: 86.69, Time: 86.69)
#   - Drone Info: (Distance: 86.69, Time: 43.35)
#
# --- Edge 27 -> 31 ---
#   - Truck Info: (Distance: 65.21, Time: 65.21)
#   - Drone Info: (Distance: 65.21, Time: 32.61)
#
# --- Edge 27 -> 32 ---
#   - Truck Info: (Distance: 25.90, Time: 25.90)
#   - Drone Info: (Distance: 25.90, Time: 12.95)
#
# --- Edge 27 -> 33 ---
#   - Truck Info: (Distance: 35.85, Time: 35.85)
#   - Drone Info: (Distance: 35.85, Time: 17.92)
#
# --- Edge 27 -> 34 ---
#   - Truck Info: (Distance: 14.14, Time: 14.14)
#   - Drone Info: (Distance: 14.14, Time: 7.07)
#
# --- Edge 27 -> 35 ---
#   - Truck Info: (Distance: 97.40, Time: 97.40)
#   - Drone Info: (Distance: 97.40, Time: 48.70)
#
# --- Edge 27 -> 36 ---
#   - Truck Info: (Distance: 80.88, Time: 80.88)
#   - Drone Info: (Distance: 80.88, Time: 40.44)
#
# --- Edge 27 -> 37 ---
#   - Truck Info: (Distance: 74.55, Time: 74.55)
#   - Drone Info: (Distance: 74.55, Time: 37.27)
#
# --- Edge 27 -> 38 ---
#   - Truck Info: (Distance: 37.85, Time: 37.85)
#   - Drone Info: (Distance: 37.85, Time: 18.92)
#
# --- Edge 27 -> 39 ---
#   - Truck Info: (Distance: 26.31, Time: 26.31)
#   - Drone Info: (Distance: 26.31, Time: 13.15)
#
# --- Edge 27 -> 40 ---
#   - Truck Info: (Distance: 39.86, Time: 39.86)
#   - Drone Info: (Distance: 39.86, Time: 19.93)
#
# --- Edge 27 -> 41 ---
#   - Truck Info: (Distance: 5.63, Time: 5.63)
#   - Drone Info: (Distance: 5.63, Time: 2.82)
#
# --- Edge 27 -> 42 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 27 -> 43 ---
#   - Truck Info: (Distance: 5.06, Time: 5.06)
#   - Drone Info: (Distance: 5.06, Time: 2.53)
#
# --- Edge 27 -> 44 ---
#   - Truck Info: (Distance: 98.74, Time: 98.74)
#   - Drone Info: (Distance: 98.74, Time: 49.37)
#
# --- Edge 27 -> 45 ---
#   - Truck Info: (Distance: 21.52, Time: 21.52)
#   - Drone Info: (Distance: 21.52, Time: 10.76)
#
# --- Edge 27 -> 46 ---
#   - Truck Info: (Distance: 51.74, Time: 51.74)
#   - Drone Info: (Distance: 51.74, Time: 25.87)
#
# --- Edge 27 -> 47 ---
#   - Truck Info: (Distance: 36.06, Time: 36.06)
#   - Drone Info: (Distance: 36.06, Time: 18.03)
#
# --- Edge 27 -> 48 ---
#   - Truck Info: (Distance: 97.25, Time: 97.25)
#   - Drone Info: (Distance: 97.25, Time: 48.63)
#
# --- Edge 27 -> 49 ---
#   - Truck Info: (Distance: 67.42, Time: 67.42)
#   - Drone Info: (Distance: 67.42, Time: 33.71)
#
# --- Edge 28 -> 0 ---
#   - Truck Info: (Distance: 16.28, Time: 16.28)
#   - Drone Info: (Distance: 16.28, Time: 8.14)
#
# --- Edge 28 -> 1 ---
#   - Truck Info: (Distance: 89.97, Time: 89.97)
#   - Drone Info: (Distance: 89.97, Time: 44.98)
#
# --- Edge 28 -> 2 ---
#   - Truck Info: (Distance: 10.13, Time: 10.13)
#   - Drone Info: (Distance: 10.13, Time: 5.06)
#
# --- Edge 28 -> 3 ---
#   - Truck Info: (Distance: 71.76, Time: 71.76)
#   - Drone Info: (Distance: 71.76, Time: 35.88)
#
# --- Edge 28 -> 4 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 28 -> 5 ---
#   - Truck Info: (Distance: 35.22, Time: 35.22)
#   - Drone Info: (Distance: 35.22, Time: 17.61)
#
# --- Edge 28 -> 6 ---
#   - Truck Info: (Distance: 52.61, Time: 52.61)
#   - Drone Info: (Distance: 52.61, Time: 26.30)
#
# --- Edge 28 -> 7 ---
#   - Truck Info: (Distance: 61.73, Time: 61.73)
#   - Drone Info: (Distance: 61.73, Time: 30.87)
#
# --- Edge 28 -> 8 ---
#   - Truck Info: (Distance: 97.58, Time: 97.58)
#   - Drone Info: (Distance: 97.58, Time: 48.79)
#
# --- Edge 28 -> 9 ---
#   - Truck Info: (Distance: 38.54, Time: 38.54)
#   - Drone Info: (Distance: 38.54, Time: 19.27)
#
# --- Edge 28 -> 10 ---
#   - Truck Info: (Distance: 43.14, Time: 43.14)
#   - Drone Info: (Distance: 43.14, Time: 21.57)
#
# --- Edge 28 -> 11 ---
#   - Truck Info: (Distance: 46.22, Time: 46.22)
#   - Drone Info: (Distance: 46.22, Time: 23.11)
#
# --- Edge 28 -> 12 ---
#   - Truck Info: (Distance: 73.76, Time: 73.76)
#   - Drone Info: (Distance: 73.76, Time: 36.88)
#
# --- Edge 28 -> 13 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 28 -> 14 ---
#   - Truck Info: (Distance: 59.05, Time: 59.05)
#   - Drone Info: (Distance: 59.05, Time: 29.52)
#
# --- Edge 28 -> 15 ---
#   - Truck Info: (Distance: 98.27, Time: 98.27)
#   - Drone Info: (Distance: 98.27, Time: 49.14)
#
# --- Edge 28 -> 16 ---
#   - Truck Info: (Distance: 62.84, Time: 62.84)
#   - Drone Info: (Distance: 62.84, Time: 31.42)
#
# --- Edge 28 -> 17 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 28 -> 18 ---
#   - Truck Info: (Distance: 90.32, Time: 90.32)
#   - Drone Info: (Distance: 90.32, Time: 45.16)
#
# --- Edge 28 -> 19 ---
#   - Truck Info: (Distance: 18.53, Time: 18.53)
#   - Drone Info: (Distance: 18.53, Time: 9.27)
#
# --- Edge 28 -> 20 ---
#   - Truck Info: (Distance: 15.26, Time: 15.26)
#   - Drone Info: (Distance: 15.26, Time: 7.63)
#
# --- Edge 28 -> 21 ---
#   - Truck Info: (Distance: 23.01, Time: 23.01)
#   - Drone Info: (Distance: 23.01, Time: 11.50)
#
# --- Edge 28 -> 22 ---
#   - Truck Info: (Distance: 35.50, Time: 35.50)
#   - Drone Info: (Distance: 35.50, Time: 17.75)
#
# --- Edge 28 -> 23 ---
#   - Truck Info: (Distance: 72.15, Time: 72.15)
#   - Drone Info: (Distance: 72.15, Time: 36.07)
#
# --- Edge 28 -> 24 ---
#   - Truck Info: (Distance: 83.64, Time: 83.64)
#   - Drone Info: (Distance: 83.64, Time: 41.82)
#
# --- Edge 28 -> 25 ---
#   - Truck Info: (Distance: 72.85, Time: 72.85)
#   - Drone Info: (Distance: 72.85, Time: 36.42)
#
# --- Edge 28 -> 26 ---
#   - Truck Info: (Distance: 15.16, Time: 15.16)
#   - Drone Info: (Distance: 15.16, Time: 7.58)
#
# --- Edge 28 -> 27 ---
#   - Truck Info: (Distance: 7.89, Time: 7.89)
#   - Drone Info: (Distance: 7.89, Time: 3.94)
#
# --- Edge 28 -> 29 ---
#   - Truck Info: (Distance: 65.35, Time: 65.35)
#   - Drone Info: (Distance: 65.35, Time: 32.67)
#
# --- Edge 28 -> 30 ---
#   - Truck Info: (Distance: 76.32, Time: 76.32)
#   - Drone Info: (Distance: 76.32, Time: 38.16)
#
# --- Edge 28 -> 31 ---
#   - Truck Info: (Distance: 46.07, Time: 46.07)
#   - Drone Info: (Distance: 46.07, Time: 23.03)
#
# --- Edge 28 -> 32 ---
#   - Truck Info: (Distance: 32.10, Time: 32.10)
#   - Drone Info: (Distance: 32.10, Time: 16.05)
#
# --- Edge 28 -> 33 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 28 -> 34 ---
#   - Truck Info: (Distance: 94.90, Time: 94.90)
#   - Drone Info: (Distance: 94.90, Time: 47.45)
#
# --- Edge 28 -> 35 ---
#   - Truck Info: (Distance: 34.02, Time: 34.02)
#   - Drone Info: (Distance: 34.02, Time: 17.01)
#
# --- Edge 28 -> 36 ---
#   - Truck Info: (Distance: 71.34, Time: 71.34)
#   - Drone Info: (Distance: 71.34, Time: 35.67)
#
# --- Edge 28 -> 37 ---
#   - Truck Info: (Distance: 30.93, Time: 30.93)
#   - Drone Info: (Distance: 30.93, Time: 15.47)
#
# --- Edge 28 -> 38 ---
#   - Truck Info: (Distance: 51.79, Time: 51.79)
#   - Drone Info: (Distance: 51.79, Time: 25.89)
#
# --- Edge 28 -> 39 ---
#   - Truck Info: (Distance: 78.92, Time: 78.92)
#   - Drone Info: (Distance: 78.92, Time: 39.46)
#
# --- Edge 28 -> 40 ---
#   - Truck Info: (Distance: 77.47, Time: 77.47)
#   - Drone Info: (Distance: 77.47, Time: 38.74)
#
# --- Edge 28 -> 41 ---
#   - Truck Info: (Distance: 95.49, Time: 95.49)
#   - Drone Info: (Distance: 95.49, Time: 47.75)
#
# --- Edge 28 -> 42 ---
#   - Truck Info: (Distance: 6.28, Time: 6.28)
#   - Drone Info: (Distance: 6.28, Time: 3.14)
#
# --- Edge 28 -> 43 ---
#   - Truck Info: (Distance: 40.02, Time: 40.02)
#   - Drone Info: (Distance: 40.02, Time: 20.01)
#
# --- Edge 28 -> 44 ---
#   - Truck Info: (Distance: 10.64, Time: 10.64)
#   - Drone Info: (Distance: 10.64, Time: 5.32)
#
# --- Edge 28 -> 45 ---
#   - Truck Info: (Distance: 37.16, Time: 37.16)
#   - Drone Info: (Distance: 37.16, Time: 18.58)
#
# --- Edge 28 -> 46 ---
#   - Truck Info: (Distance: 36.29, Time: 36.29)
#   - Drone Info: (Distance: 36.29, Time: 18.14)
#
# --- Edge 28 -> 47 ---
#   - Truck Info: (Distance: 89.04, Time: 89.04)
#   - Drone Info: (Distance: 89.04, Time: 44.52)
#
# --- Edge 28 -> 48 ---
#   - Truck Info: (Distance: 91.65, Time: 91.65)
#   - Drone Info: (Distance: 91.65, Time: 45.83)
#
# --- Edge 28 -> 49 ---
#   - Truck Info: (Distance: 27.54, Time: 27.54)
#   - Drone Info: (Distance: 27.54, Time: 13.77)
#
# --- Edge 29 -> 0 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 29 -> 1 ---
#   - Truck Info: (Distance: 76.49, Time: 76.49)
#   - Drone Info: (Distance: 76.49, Time: 38.24)
#
# --- Edge 29 -> 2 ---
#   - Truck Info: (Distance: 25.35, Time: 25.35)
#   - Drone Info: (Distance: 25.35, Time: 12.68)
#
# --- Edge 29 -> 3 ---
#   - Truck Info: (Distance: 46.48, Time: 46.48)
#   - Drone Info: (Distance: 46.48, Time: 23.24)
#
# --- Edge 29 -> 4 ---
#   - Truck Info: (Distance: 87.59, Time: 87.59)
#   - Drone Info: (Distance: 87.59, Time: 43.80)
#
# --- Edge 29 -> 5 ---
#   - Truck Info: (Distance: 71.49, Time: 71.49)
#   - Drone Info: (Distance: 71.49, Time: 35.74)
#
# --- Edge 29 -> 6 ---
#   - Truck Info: (Distance: 31.50, Time: 31.50)
#   - Drone Info: (Distance: 31.50, Time: 15.75)
#
# --- Edge 29 -> 7 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 29 -> 8 ---
#   - Truck Info: (Distance: 12.00, Time: 12.00)
#   - Drone Info: (Distance: 12.00, Time: 6.00)
#
# --- Edge 29 -> 9 ---
#   - Truck Info: (Distance: 61.54, Time: 61.54)
#   - Drone Info: (Distance: 61.54, Time: 30.77)
#
# --- Edge 29 -> 10 ---
#   - Truck Info: (Distance: 16.35, Time: 16.35)
#   - Drone Info: (Distance: 16.35, Time: 8.17)
#
# --- Edge 29 -> 11 ---
#   - Truck Info: (Distance: 24.99, Time: 24.99)
#   - Drone Info: (Distance: 24.99, Time: 12.50)
#
# --- Edge 29 -> 12 ---
#   - Truck Info: (Distance: 16.13, Time: 16.13)
#   - Drone Info: (Distance: 16.13, Time: 8.06)
#
# --- Edge 29 -> 13 ---
#   - Truck Info: (Distance: 14.94, Time: 14.94)
#   - Drone Info: (Distance: 14.94, Time: 7.47)
#
# --- Edge 29 -> 14 ---
#   - Truck Info: (Distance: 81.03, Time: 81.03)
#   - Drone Info: (Distance: 81.03, Time: 40.52)
#
# --- Edge 29 -> 15 ---
#   - Truck Info: (Distance: 95.65, Time: 95.65)
#   - Drone Info: (Distance: 95.65, Time: 47.82)
#
# --- Edge 29 -> 16 ---
#   - Truck Info: (Distance: 32.78, Time: 32.78)
#   - Drone Info: (Distance: 32.78, Time: 16.39)
#
# --- Edge 29 -> 17 ---
#   - Truck Info: (Distance: 43.15, Time: 43.15)
#   - Drone Info: (Distance: 43.15, Time: 21.58)
#
# --- Edge 29 -> 18 ---
#   - Truck Info: (Distance: 56.59, Time: 56.59)
#   - Drone Info: (Distance: 56.59, Time: 28.30)
#
# --- Edge 29 -> 19 ---
#   - Truck Info: (Distance: 9.05, Time: 9.05)
#   - Drone Info: (Distance: 9.05, Time: 4.52)
#
# --- Edge 29 -> 20 ---
#   - Truck Info: (Distance: 61.47, Time: 61.47)
#   - Drone Info: (Distance: 61.47, Time: 30.73)
#
# --- Edge 29 -> 21 ---
#   - Truck Info: (Distance: 65.98, Time: 65.98)
#   - Drone Info: (Distance: 65.98, Time: 32.99)
#
# --- Edge 29 -> 22 ---
#   - Truck Info: (Distance: 18.86, Time: 18.86)
#   - Drone Info: (Distance: 18.86, Time: 9.43)
#
# --- Edge 29 -> 23 ---
#   - Truck Info: (Distance: 37.95, Time: 37.95)
#   - Drone Info: (Distance: 37.95, Time: 18.98)
#
# --- Edge 29 -> 24 ---
#   - Truck Info: (Distance: 70.03, Time: 70.03)
#   - Drone Info: (Distance: 70.03, Time: 35.01)
#
# --- Edge 29 -> 25 ---
#   - Truck Info: (Distance: 71.66, Time: 71.66)
#   - Drone Info: (Distance: 71.66, Time: 35.83)
#
# --- Edge 29 -> 26 ---
#   - Truck Info: (Distance: 94.67, Time: 94.67)
#   - Drone Info: (Distance: 94.67, Time: 47.34)
#
# --- Edge 29 -> 27 ---
#   - Truck Info: (Distance: 47.39, Time: 47.39)
#   - Drone Info: (Distance: 47.39, Time: 23.69)
#
# --- Edge 29 -> 28 ---
#   - Truck Info: (Distance: 88.24, Time: 88.24)
#   - Drone Info: (Distance: 88.24, Time: 44.12)
#
# --- Edge 29 -> 30 ---
#   - Truck Info: (Distance: 79.93, Time: 79.93)
#   - Drone Info: (Distance: 79.93, Time: 39.96)
#
# --- Edge 29 -> 31 ---
#   - Truck Info: (Distance: 36.55, Time: 36.55)
#   - Drone Info: (Distance: 36.55, Time: 18.27)
#
# --- Edge 29 -> 32 ---
#   - Truck Info: (Distance: 48.18, Time: 48.18)
#   - Drone Info: (Distance: 48.18, Time: 24.09)
#
# --- Edge 29 -> 33 ---
#   - Truck Info: (Distance: 6.74, Time: 6.74)
#   - Drone Info: (Distance: 6.74, Time: 3.37)
#
# --- Edge 29 -> 34 ---
#   - Truck Info: (Distance: 25.75, Time: 25.75)
#   - Drone Info: (Distance: 25.75, Time: 12.87)
#
# --- Edge 29 -> 35 ---
#   - Truck Info: (Distance: 17.53, Time: 17.53)
#   - Drone Info: (Distance: 17.53, Time: 8.76)
#
# --- Edge 29 -> 36 ---
#   - Truck Info: (Distance: 47.45, Time: 47.45)
#   - Drone Info: (Distance: 47.45, Time: 23.72)
#
# --- Edge 29 -> 37 ---
#   - Truck Info: (Distance: 23.06, Time: 23.06)
#   - Drone Info: (Distance: 23.06, Time: 11.53)
#
# --- Edge 29 -> 38 ---
#   - Truck Info: (Distance: 40.24, Time: 40.24)
#   - Drone Info: (Distance: 40.24, Time: 20.12)
#
# --- Edge 29 -> 39 ---
#   - Truck Info: (Distance: 38.41, Time: 38.41)
#   - Drone Info: (Distance: 38.41, Time: 19.20)
#
# --- Edge 29 -> 40 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 29 -> 41 ---
#   - Truck Info: (Distance: 8.41, Time: 8.41)
#   - Drone Info: (Distance: 8.41, Time: 4.20)
#
# --- Edge 29 -> 42 ---
#   - Truck Info: (Distance: 88.48, Time: 88.48)
#   - Drone Info: (Distance: 88.48, Time: 44.24)
#
# --- Edge 29 -> 43 ---
#   - Truck Info: (Distance: 15.48, Time: 15.48)
#   - Drone Info: (Distance: 15.48, Time: 7.74)
#
# --- Edge 29 -> 44 ---
#   - Truck Info: (Distance: 26.11, Time: 26.11)
#   - Drone Info: (Distance: 26.11, Time: 13.06)
#
# --- Edge 29 -> 45 ---
#   - Truck Info: (Distance: 7.91, Time: 7.91)
#   - Drone Info: (Distance: 7.91, Time: 3.96)
#
# --- Edge 29 -> 46 ---
#   - Truck Info: (Distance: 37.23, Time: 37.23)
#   - Drone Info: (Distance: 37.23, Time: 18.62)
#
# --- Edge 29 -> 47 ---
#   - Truck Info: (Distance: 32.89, Time: 32.89)
#   - Drone Info: (Distance: 32.89, Time: 16.44)
#
# --- Edge 29 -> 48 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 29 -> 49 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 30 -> 0 ---
#   - Truck Info: (Distance: 34.82, Time: 34.82)
#   - Drone Info: (Distance: 34.82, Time: 17.41)
#
# --- Edge 30 -> 1 ---
#   - Truck Info: (Distance: 47.61, Time: 47.61)
#   - Drone Info: (Distance: 47.61, Time: 23.80)
#
# --- Edge 30 -> 2 ---
#   - Truck Info: (Distance: 27.86, Time: 27.86)
#   - Drone Info: (Distance: 27.86, Time: 13.93)
#
# --- Edge 30 -> 3 ---
#   - Truck Info: (Distance: 64.02, Time: 64.02)
#   - Drone Info: (Distance: 64.02, Time: 32.01)
#
# --- Edge 30 -> 4 ---
#   - Truck Info: (Distance: 15.79, Time: 15.79)
#   - Drone Info: (Distance: 15.79, Time: 7.90)
#
# --- Edge 30 -> 5 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 30 -> 6 ---
#   - Truck Info: (Distance: 31.11, Time: 31.11)
#   - Drone Info: (Distance: 31.11, Time: 15.55)
#
# --- Edge 30 -> 7 ---
#   - Truck Info: (Distance: 32.44, Time: 32.44)
#   - Drone Info: (Distance: 32.44, Time: 16.22)
#
# --- Edge 30 -> 8 ---
#   - Truck Info: (Distance: 18.77, Time: 18.77)
#   - Drone Info: (Distance: 18.77, Time: 9.38)
#
# --- Edge 30 -> 9 ---
#   - Truck Info: (Distance: 30.26, Time: 30.26)
#   - Drone Info: (Distance: 30.26, Time: 15.13)
#
# --- Edge 30 -> 10 ---
#   - Truck Info: (Distance: 17.86, Time: 17.86)
#   - Drone Info: (Distance: 17.86, Time: 8.93)
#
# --- Edge 30 -> 11 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 30 -> 12 ---
#   - Truck Info: (Distance: 69.59, Time: 69.59)
#   - Drone Info: (Distance: 69.59, Time: 34.80)
#
# --- Edge 30 -> 13 ---
#   - Truck Info: (Distance: 89.60, Time: 89.60)
#   - Drone Info: (Distance: 89.60, Time: 44.80)
#
# --- Edge 30 -> 14 ---
#   - Truck Info: (Distance: 22.68, Time: 22.68)
#   - Drone Info: (Distance: 22.68, Time: 11.34)
#
# --- Edge 30 -> 15 ---
#   - Truck Info: (Distance: 22.55, Time: 22.55)
#   - Drone Info: (Distance: 22.55, Time: 11.28)
#
# --- Edge 30 -> 16 ---
#   - Truck Info: (Distance: 10.06, Time: 10.06)
#   - Drone Info: (Distance: 10.06, Time: 5.03)
#
# --- Edge 30 -> 17 ---
#   - Truck Info: (Distance: 94.09, Time: 94.09)
#   - Drone Info: (Distance: 94.09, Time: 47.04)
#
# --- Edge 30 -> 18 ---
#   - Truck Info: (Distance: 61.67, Time: 61.67)
#   - Drone Info: (Distance: 61.67, Time: 30.84)
#
# --- Edge 30 -> 19 ---
#   - Truck Info: (Distance: 40.47, Time: 40.47)
#   - Drone Info: (Distance: 40.47, Time: 20.24)
#
# --- Edge 30 -> 20 ---
#   - Truck Info: (Distance: 28.61, Time: 28.61)
#   - Drone Info: (Distance: 28.61, Time: 14.30)
#
# --- Edge 30 -> 21 ---
#   - Truck Info: (Distance: 10.04, Time: 10.04)
#   - Drone Info: (Distance: 10.04, Time: 5.02)
#
# --- Edge 30 -> 22 ---
#   - Truck Info: (Distance: 91.85, Time: 91.85)
#   - Drone Info: (Distance: 91.85, Time: 45.92)
#
# --- Edge 30 -> 23 ---
#   - Truck Info: (Distance: 40.38, Time: 40.38)
#   - Drone Info: (Distance: 40.38, Time: 20.19)
#
# --- Edge 30 -> 24 ---
#   - Truck Info: (Distance: 67.45, Time: 67.45)
#   - Drone Info: (Distance: 67.45, Time: 33.72)
#
# --- Edge 30 -> 25 ---
#   - Truck Info: (Distance: 60.02, Time: 60.02)
#   - Drone Info: (Distance: 60.02, Time: 30.01)
#
# --- Edge 30 -> 26 ---
#   - Truck Info: (Distance: 5.97, Time: 5.97)
#   - Drone Info: (Distance: 5.97, Time: 2.99)
#
# --- Edge 30 -> 27 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 30 -> 28 ---
#   - Truck Info: (Distance: 73.77, Time: 73.77)
#   - Drone Info: (Distance: 73.77, Time: 36.88)
#
# --- Edge 30 -> 29 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 30 -> 31 ---
#   - Truck Info: (Distance: 47.77, Time: 47.77)
#   - Drone Info: (Distance: 47.77, Time: 23.88)
#
# --- Edge 30 -> 32 ---
#   - Truck Info: (Distance: 48.11, Time: 48.11)
#   - Drone Info: (Distance: 48.11, Time: 24.06)
#
# --- Edge 30 -> 33 ---
#   - Truck Info: (Distance: 50.30, Time: 50.30)
#   - Drone Info: (Distance: 50.30, Time: 25.15)
#
# --- Edge 30 -> 34 ---
#   - Truck Info: (Distance: 83.58, Time: 83.58)
#   - Drone Info: (Distance: 83.58, Time: 41.79)
#
# --- Edge 30 -> 35 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 30 -> 36 ---
#   - Truck Info: (Distance: 63.07, Time: 63.07)
#   - Drone Info: (Distance: 63.07, Time: 31.53)
#
# --- Edge 30 -> 37 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 30 -> 38 ---
#   - Truck Info: (Distance: 7.64, Time: 7.64)
#   - Drone Info: (Distance: 7.64, Time: 3.82)
#
# --- Edge 30 -> 39 ---
#   - Truck Info: (Distance: 96.46, Time: 96.46)
#   - Drone Info: (Distance: 96.46, Time: 48.23)
#
# --- Edge 30 -> 40 ---
#   - Truck Info: (Distance: 74.46, Time: 74.46)
#   - Drone Info: (Distance: 74.46, Time: 37.23)
#
# --- Edge 30 -> 41 ---
#   - Truck Info: (Distance: 75.24, Time: 75.24)
#   - Drone Info: (Distance: 75.24, Time: 37.62)
#
# --- Edge 30 -> 42 ---
#   - Truck Info: (Distance: 78.07, Time: 78.07)
#   - Drone Info: (Distance: 78.07, Time: 39.04)
#
# --- Edge 30 -> 43 ---
#   - Truck Info: (Distance: 22.99, Time: 22.99)
#   - Drone Info: (Distance: 22.99, Time: 11.50)
#
# --- Edge 30 -> 44 ---
#   - Truck Info: (Distance: 15.86, Time: 15.86)
#   - Drone Info: (Distance: 15.86, Time: 7.93)
#
# --- Edge 30 -> 45 ---
#   - Truck Info: (Distance: 34.37, Time: 34.37)
#   - Drone Info: (Distance: 34.37, Time: 17.18)
#
# --- Edge 30 -> 46 ---
#   - Truck Info: (Distance: 54.23, Time: 54.23)
#   - Drone Info: (Distance: 54.23, Time: 27.11)
#
# --- Edge 30 -> 47 ---
#   - Truck Info: (Distance: 76.79, Time: 76.79)
#   - Drone Info: (Distance: 76.79, Time: 38.40)
#
# --- Edge 30 -> 48 ---
#   - Truck Info: (Distance: 87.63, Time: 87.63)
#   - Drone Info: (Distance: 87.63, Time: 43.81)
#
# --- Edge 30 -> 49 ---
#   - Truck Info: (Distance: 59.91, Time: 59.91)
#   - Drone Info: (Distance: 59.91, Time: 29.96)
#
# --- Edge 31 -> 0 ---
#   - Truck Info: (Distance: 58.00, Time: 58.00)
#   - Drone Info: (Distance: 58.00, Time: 29.00)
#
# --- Edge 31 -> 1 ---
#   - Truck Info: (Distance: 42.99, Time: 42.99)
#   - Drone Info: (Distance: 42.99, Time: 21.50)
#
# --- Edge 31 -> 2 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 31 -> 3 ---
#   - Truck Info: (Distance: 17.56, Time: 17.56)
#   - Drone Info: (Distance: 17.56, Time: 8.78)
#
# --- Edge 31 -> 4 ---
#   - Truck Info: (Distance: 77.56, Time: 77.56)
#   - Drone Info: (Distance: 77.56, Time: 38.78)
#
# --- Edge 31 -> 5 ---
#   - Truck Info: (Distance: 50.26, Time: 50.26)
#   - Drone Info: (Distance: 50.26, Time: 25.13)
#
# --- Edge 31 -> 6 ---
#   - Truck Info: (Distance: 79.17, Time: 79.17)
#   - Drone Info: (Distance: 79.17, Time: 39.58)
#
# --- Edge 31 -> 7 ---
#   - Truck Info: (Distance: 9.50, Time: 9.50)
#   - Drone Info: (Distance: 9.50, Time: 4.75)
#
# --- Edge 31 -> 8 ---
#   - Truck Info: (Distance: 77.21, Time: 77.21)
#   - Drone Info: (Distance: 77.21, Time: 38.61)
#
# --- Edge 31 -> 9 ---
#   - Truck Info: (Distance: 28.39, Time: 28.39)
#   - Drone Info: (Distance: 28.39, Time: 14.19)
#
# --- Edge 31 -> 10 ---
#   - Truck Info: (Distance: 8.85, Time: 8.85)
#   - Drone Info: (Distance: 8.85, Time: 4.43)
#
# --- Edge 31 -> 11 ---
#   - Truck Info: (Distance: 47.81, Time: 47.81)
#   - Drone Info: (Distance: 47.81, Time: 23.91)
#
# --- Edge 31 -> 12 ---
#   - Truck Info: (Distance: 49.36, Time: 49.36)
#   - Drone Info: (Distance: 49.36, Time: 24.68)
#
# --- Edge 31 -> 13 ---
#   - Truck Info: (Distance: 19.58, Time: 19.58)
#   - Drone Info: (Distance: 19.58, Time: 9.79)
#
# --- Edge 31 -> 14 ---
#   - Truck Info: (Distance: 19.70, Time: 19.70)
#   - Drone Info: (Distance: 19.70, Time: 9.85)
#
# --- Edge 31 -> 15 ---
#   - Truck Info: (Distance: 77.04, Time: 77.04)
#   - Drone Info: (Distance: 77.04, Time: 38.52)
#
# --- Edge 31 -> 16 ---
#   - Truck Info: (Distance: 85.25, Time: 85.25)
#   - Drone Info: (Distance: 85.25, Time: 42.62)
#
# --- Edge 31 -> 17 ---
#   - Truck Info: (Distance: 80.51, Time: 80.51)
#   - Drone Info: (Distance: 80.51, Time: 40.25)
#
# --- Edge 31 -> 18 ---
#   - Truck Info: (Distance: 89.09, Time: 89.09)
#   - Drone Info: (Distance: 89.09, Time: 44.54)
#
# --- Edge 31 -> 19 ---
#   - Truck Info: (Distance: 73.90, Time: 73.90)
#   - Drone Info: (Distance: 73.90, Time: 36.95)
#
# --- Edge 31 -> 20 ---
#   - Truck Info: (Distance: 93.39, Time: 93.39)
#   - Drone Info: (Distance: 93.39, Time: 46.70)
#
# --- Edge 31 -> 21 ---
#   - Truck Info: (Distance: 19.48, Time: 19.48)
#   - Drone Info: (Distance: 19.48, Time: 9.74)
#
# --- Edge 31 -> 22 ---
#   - Truck Info: (Distance: 39.33, Time: 39.33)
#   - Drone Info: (Distance: 39.33, Time: 19.67)
#
# --- Edge 31 -> 23 ---
#   - Truck Info: (Distance: 68.17, Time: 68.17)
#   - Drone Info: (Distance: 68.17, Time: 34.08)
#
# --- Edge 31 -> 24 ---
#   - Truck Info: (Distance: 72.76, Time: 72.76)
#   - Drone Info: (Distance: 72.76, Time: 36.38)
#
# --- Edge 31 -> 25 ---
#   - Truck Info: (Distance: 5.14, Time: 5.14)
#   - Drone Info: (Distance: 5.14, Time: 2.57)
#
# --- Edge 31 -> 26 ---
#   - Truck Info: (Distance: 16.24, Time: 16.24)
#   - Drone Info: (Distance: 16.24, Time: 8.12)
#
# --- Edge 31 -> 27 ---
#   - Truck Info: (Distance: 9.02, Time: 9.02)
#   - Drone Info: (Distance: 9.02, Time: 4.51)
#
# --- Edge 31 -> 28 ---
#   - Truck Info: (Distance: 57.98, Time: 57.98)
#   - Drone Info: (Distance: 57.98, Time: 28.99)
#
# --- Edge 31 -> 29 ---
#   - Truck Info: (Distance: 41.36, Time: 41.36)
#   - Drone Info: (Distance: 41.36, Time: 20.68)
#
# --- Edge 31 -> 30 ---
#   - Truck Info: (Distance: 24.66, Time: 24.66)
#   - Drone Info: (Distance: 24.66, Time: 12.33)
#
# --- Edge 31 -> 32 ---
#   - Truck Info: (Distance: 44.94, Time: 44.94)
#   - Drone Info: (Distance: 44.94, Time: 22.47)
#
# --- Edge 31 -> 33 ---
#   - Truck Info: (Distance: 58.55, Time: 58.55)
#   - Drone Info: (Distance: 58.55, Time: 29.27)
#
# --- Edge 31 -> 34 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 31 -> 35 ---
#   - Truck Info: (Distance: 58.75, Time: 58.75)
#   - Drone Info: (Distance: 58.75, Time: 29.38)
#
# --- Edge 31 -> 36 ---
#   - Truck Info: (Distance: 47.71, Time: 47.71)
#   - Drone Info: (Distance: 47.71, Time: 23.86)
#
# --- Edge 31 -> 37 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 31 -> 38 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 31 -> 39 ---
#   - Truck Info: (Distance: 51.22, Time: 51.22)
#   - Drone Info: (Distance: 51.22, Time: 25.61)
#
# --- Edge 31 -> 40 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 31 -> 41 ---
#   - Truck Info: (Distance: 83.47, Time: 83.47)
#   - Drone Info: (Distance: 83.47, Time: 41.73)
#
# --- Edge 31 -> 42 ---
#   - Truck Info: (Distance: 96.21, Time: 96.21)
#   - Drone Info: (Distance: 96.21, Time: 48.11)
#
# --- Edge 31 -> 43 ---
#   - Truck Info: (Distance: 34.39, Time: 34.39)
#   - Drone Info: (Distance: 34.39, Time: 17.20)
#
# --- Edge 31 -> 44 ---
#   - Truck Info: (Distance: 73.26, Time: 73.26)
#   - Drone Info: (Distance: 73.26, Time: 36.63)
#
# --- Edge 31 -> 45 ---
#   - Truck Info: (Distance: 87.66, Time: 87.66)
#   - Drone Info: (Distance: 87.66, Time: 43.83)
#
# --- Edge 31 -> 46 ---
#   - Truck Info: (Distance: 27.07, Time: 27.07)
#   - Drone Info: (Distance: 27.07, Time: 13.53)
#
# --- Edge 31 -> 47 ---
#   - Truck Info: (Distance: 73.36, Time: 73.36)
#   - Drone Info: (Distance: 73.36, Time: 36.68)
#
# --- Edge 31 -> 48 ---
#   - Truck Info: (Distance: 6.90, Time: 6.90)
#   - Drone Info: (Distance: 6.90, Time: 3.45)
#
# --- Edge 31 -> 49 ---
#   - Truck Info: (Distance: 29.54, Time: 29.54)
#   - Drone Info: (Distance: 29.54, Time: 14.77)
#
# --- Edge 32 -> 0 ---
#   - Truck Info: (Distance: 6.79, Time: 6.79)
#   - Drone Info: (Distance: 6.79, Time: 3.40)
#
# --- Edge 32 -> 1 ---
#   - Truck Info: (Distance: 68.45, Time: 68.45)
#   - Drone Info: (Distance: 68.45, Time: 34.22)
#
# --- Edge 32 -> 2 ---
#   - Truck Info: (Distance: 39.10, Time: 39.10)
#   - Drone Info: (Distance: 39.10, Time: 19.55)
#
# --- Edge 32 -> 3 ---
#   - Truck Info: (Distance: 98.28, Time: 98.28)
#   - Drone Info: (Distance: 98.28, Time: 49.14)
#
# --- Edge 32 -> 4 ---
#   - Truck Info: (Distance: 80.09, Time: 80.09)
#   - Drone Info: (Distance: 80.09, Time: 40.05)
#
# --- Edge 32 -> 5 ---
#   - Truck Info: (Distance: 98.79, Time: 98.79)
#   - Drone Info: (Distance: 98.79, Time: 49.39)
#
# --- Edge 32 -> 6 ---
#   - Truck Info: (Distance: 88.83, Time: 88.83)
#   - Drone Info: (Distance: 88.83, Time: 44.41)
#
# --- Edge 32 -> 7 ---
#   - Truck Info: (Distance: 72.54, Time: 72.54)
#   - Drone Info: (Distance: 72.54, Time: 36.27)
#
# --- Edge 32 -> 8 ---
#   - Truck Info: (Distance: 99.96, Time: 99.96)
#   - Drone Info: (Distance: 99.96, Time: 49.98)
#
# --- Edge 32 -> 9 ---
#   - Truck Info: (Distance: 52.61, Time: 52.61)
#   - Drone Info: (Distance: 52.61, Time: 26.30)
#
# --- Edge 32 -> 10 ---
#   - Truck Info: (Distance: 19.02, Time: 19.02)
#   - Drone Info: (Distance: 19.02, Time: 9.51)
#
# --- Edge 32 -> 11 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 32 -> 12 ---
#   - Truck Info: (Distance: 74.95, Time: 74.95)
#   - Drone Info: (Distance: 74.95, Time: 37.48)
#
# --- Edge 32 -> 13 ---
#   - Truck Info: (Distance: 98.62, Time: 98.62)
#   - Drone Info: (Distance: 98.62, Time: 49.31)
#
# --- Edge 32 -> 14 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 32 -> 15 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 32 -> 16 ---
#   - Truck Info: (Distance: 95.96, Time: 95.96)
#   - Drone Info: (Distance: 95.96, Time: 47.98)
#
# --- Edge 32 -> 17 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 32 -> 18 ---
#   - Truck Info: (Distance: 65.44, Time: 65.44)
#   - Drone Info: (Distance: 65.44, Time: 32.72)
#
# --- Edge 32 -> 19 ---
#   - Truck Info: (Distance: 79.75, Time: 79.75)
#   - Drone Info: (Distance: 79.75, Time: 39.87)
#
# --- Edge 32 -> 20 ---
#   - Truck Info: (Distance: 72.55, Time: 72.55)
#   - Drone Info: (Distance: 72.55, Time: 36.28)
#
# --- Edge 32 -> 21 ---
#   - Truck Info: (Distance: 90.50, Time: 90.50)
#   - Drone Info: (Distance: 90.50, Time: 45.25)
#
# --- Edge 32 -> 22 ---
#   - Truck Info: (Distance: 34.95, Time: 34.95)
#   - Drone Info: (Distance: 34.95, Time: 17.48)
#
# --- Edge 32 -> 23 ---
#   - Truck Info: (Distance: 67.13, Time: 67.13)
#   - Drone Info: (Distance: 67.13, Time: 33.57)
#
# --- Edge 32 -> 24 ---
#   - Truck Info: (Distance: 45.09, Time: 45.09)
#   - Drone Info: (Distance: 45.09, Time: 22.55)
#
# --- Edge 32 -> 25 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 32 -> 26 ---
#   - Truck Info: (Distance: 60.40, Time: 60.40)
#   - Drone Info: (Distance: 60.40, Time: 30.20)
#
# --- Edge 32 -> 27 ---
#   - Truck Info: (Distance: 36.15, Time: 36.15)
#   - Drone Info: (Distance: 36.15, Time: 18.07)
#
# --- Edge 32 -> 28 ---
#   - Truck Info: (Distance: 24.62, Time: 24.62)
#   - Drone Info: (Distance: 24.62, Time: 12.31)
#
# --- Edge 32 -> 29 ---
#   - Truck Info: (Distance: 94.72, Time: 94.72)
#   - Drone Info: (Distance: 94.72, Time: 47.36)
#
# --- Edge 32 -> 30 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 32 -> 31 ---
#   - Truck Info: (Distance: 42.63, Time: 42.63)
#   - Drone Info: (Distance: 42.63, Time: 21.31)
#
# --- Edge 32 -> 33 ---
#   - Truck Info: (Distance: 67.21, Time: 67.21)
#   - Drone Info: (Distance: 67.21, Time: 33.60)
#
# --- Edge 32 -> 34 ---
#   - Truck Info: (Distance: 35.59, Time: 35.59)
#   - Drone Info: (Distance: 35.59, Time: 17.80)
#
# --- Edge 32 -> 35 ---
#   - Truck Info: (Distance: 23.64, Time: 23.64)
#   - Drone Info: (Distance: 23.64, Time: 11.82)
#
# --- Edge 32 -> 36 ---
#   - Truck Info: (Distance: 92.23, Time: 92.23)
#   - Drone Info: (Distance: 92.23, Time: 46.11)
#
# --- Edge 32 -> 37 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 32 -> 38 ---
#   - Truck Info: (Distance: 30.41, Time: 30.41)
#   - Drone Info: (Distance: 30.41, Time: 15.20)
#
# --- Edge 32 -> 39 ---
#   - Truck Info: (Distance: 81.57, Time: 81.57)
#   - Drone Info: (Distance: 81.57, Time: 40.78)
#
# --- Edge 32 -> 40 ---
#   - Truck Info: (Distance: 79.55, Time: 79.55)
#   - Drone Info: (Distance: 79.55, Time: 39.77)
#
# --- Edge 32 -> 41 ---
#   - Truck Info: (Distance: 39.97, Time: 39.97)
#   - Drone Info: (Distance: 39.97, Time: 19.98)
#
# --- Edge 32 -> 42 ---
#   - Truck Info: (Distance: 80.37, Time: 80.37)
#   - Drone Info: (Distance: 80.37, Time: 40.18)
#
# --- Edge 32 -> 43 ---
#   - Truck Info: (Distance: 98.80, Time: 98.80)
#   - Drone Info: (Distance: 98.80, Time: 49.40)
#
# --- Edge 32 -> 44 ---
#   - Truck Info: (Distance: 40.40, Time: 40.40)
#   - Drone Info: (Distance: 40.40, Time: 20.20)
#
# --- Edge 32 -> 45 ---
#   - Truck Info: (Distance: 40.38, Time: 40.38)
#   - Drone Info: (Distance: 40.38, Time: 20.19)
#
# --- Edge 32 -> 46 ---
#   - Truck Info: (Distance: 68.77, Time: 68.77)
#   - Drone Info: (Distance: 68.77, Time: 34.38)
#
# --- Edge 32 -> 47 ---
#   - Truck Info: (Distance: 69.98, Time: 69.98)
#   - Drone Info: (Distance: 69.98, Time: 34.99)
#
# --- Edge 32 -> 48 ---
#   - Truck Info: (Distance: 41.73, Time: 41.73)
#   - Drone Info: (Distance: 41.73, Time: 20.86)
#
# --- Edge 32 -> 49 ---
#   - Truck Info: (Distance: 84.15, Time: 84.15)
#   - Drone Info: (Distance: 84.15, Time: 42.08)
#
# --- Edge 33 -> 0 ---
#   - Truck Info: (Distance: 96.48, Time: 96.48)
#   - Drone Info: (Distance: 96.48, Time: 48.24)
#
# --- Edge 33 -> 1 ---
#   - Truck Info: (Distance: 59.66, Time: 59.66)
#   - Drone Info: (Distance: 59.66, Time: 29.83)
#
# ...
#   - Drone Info: (Distance: 43.67, Time: 21.84)
#
# --- Edge 47 -> 31 ---
#   - Truck Info: (Distance: 99.83, Time: 99.83)
#   - Drone Info: (Distance: 99.83, Time: 49.91)
#
# --- Edge 47 -> 32 ---
#   - Truck Info: (Distance: 95.32, Time: 95.32)
#   - Drone Info: (Distance: 95.32, Time: 47.66)
#
# --- Edge 47 -> 33 ---
#   - Truck Info: (Distance: 10.55, Time: 10.55)
#   - Drone Info: (Distance: 10.55, Time: 5.28)
#
# --- Edge 47 -> 34 ---
#   - Truck Info: (Distance: 65.26, Time: 65.26)
#   - Drone Info: (Distance: 65.26, Time: 32.63)
#
# --- Edge 47 -> 35 ---
#   - Truck Info: (Distance: 80.37, Time: 80.37)
#   - Drone Info: (Distance: 80.37, Time: 40.19)
#
# --- Edge 47 -> 36 ---
#   - Truck Info: (Distance: 25.42, Time: 25.42)
#   - Drone Info: (Distance: 25.42, Time: 12.71)
#
# --- Edge 47 -> 37 ---
#   - Truck Info: (Distance: 64.23, Time: 64.23)
#   - Drone Info: (Distance: 64.23, Time: 32.11)
#
# --- Edge 47 -> 38 ---
#   - Truck Info: (Distance: 63.98, Time: 63.98)
#   - Drone Info: (Distance: 63.98, Time: 31.99)
#
# --- Edge 47 -> 39 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 47 -> 40 ---
#   - Truck Info: (Distance: 65.06, Time: 65.06)
#   - Drone Info: (Distance: 65.06, Time: 32.53)
#
# --- Edge 47 -> 41 ---
#   - Truck Info: (Distance: 75.38, Time: 75.38)
#   - Drone Info: (Distance: 75.38, Time: 37.69)
#
# --- Edge 47 -> 42 ---
#   - Truck Info: (Distance: 22.76, Time: 22.76)
#   - Drone Info: (Distance: 22.76, Time: 11.38)
#
# --- Edge 47 -> 43 ---
#   - Truck Info: (Distance: 64.43, Time: 64.43)
#   - Drone Info: (Distance: 64.43, Time: 32.21)
#
# --- Edge 47 -> 44 ---
#   - Truck Info: (Distance: 83.89, Time: 83.89)
#   - Drone Info: (Distance: 83.89, Time: 41.95)
#
# --- Edge 47 -> 45 ---
#   - Truck Info: (Distance: 19.27, Time: 19.27)
#   - Drone Info: (Distance: 19.27, Time: 9.63)
#
# --- Edge 47 -> 46 ---
#   - Truck Info: (Distance: 36.01, Time: 36.01)
#   - Drone Info: (Distance: 36.01, Time: 18.00)
#
# --- Edge 47 -> 48 ---
#   - Truck Info: (Distance: 97.13, Time: 97.13)
#   - Drone Info: (Distance: 97.13, Time: 48.56)
#
# --- Edge 47 -> 49 ---
#   - Truck Info: (Distance: 18.40, Time: 18.40)
#   - Drone Info: (Distance: 18.40, Time: 9.20)
#
# --- Edge 48 -> 0 ---
#   - Truck Info: (Distance: 84.17, Time: 84.17)
#   - Drone Info: (Distance: 84.17, Time: 42.08)
#
# --- Edge 48 -> 1 ---
#   - Truck Info: (Distance: 41.21, Time: 41.21)
#   - Drone Info: (Distance: 41.21, Time: 20.61)
#
# --- Edge 48 -> 2 ---
#   - Truck Info: (Distance: 41.86, Time: 41.86)
#   - Drone Info: (Distance: 41.86, Time: 20.93)
#
# --- Edge 48 -> 3 ---
#   - Truck Info: (Distance: 17.09, Time: 17.09)
#   - Drone Info: (Distance: 17.09, Time: 8.55)
#
# --- Edge 48 -> 4 ---
#   - Truck Info: (Distance: 49.60, Time: 49.60)
#   - Drone Info: (Distance: 49.60, Time: 24.80)
#
# --- Edge 48 -> 5 ---
#   - Truck Info: (Distance: 74.77, Time: 74.77)
#   - Drone Info: (Distance: 74.77, Time: 37.39)
#
# --- Edge 48 -> 6 ---
#   - Truck Info: (Distance: 49.79, Time: 49.79)
#   - Drone Info: (Distance: 49.79, Time: 24.90)
#
# --- Edge 48 -> 7 ---
#   - Truck Info: (Distance: 57.75, Time: 57.75)
#   - Drone Info: (Distance: 57.75, Time: 28.87)
#
# --- Edge 48 -> 8 ---
#   - Truck Info: (Distance: 86.78, Time: 86.78)
#   - Drone Info: (Distance: 86.78, Time: 43.39)
#
# --- Edge 48 -> 9 ---
#   - Truck Info: (Distance: 50.06, Time: 50.06)
#   - Drone Info: (Distance: 50.06, Time: 25.03)
#
# --- Edge 48 -> 10 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 48 -> 11 ---
#   - Truck Info: (Distance: 44.43, Time: 44.43)
#   - Drone Info: (Distance: 44.43, Time: 22.22)
#
# --- Edge 48 -> 12 ---
#   - Truck Info: (Distance: 32.96, Time: 32.96)
#   - Drone Info: (Distance: 32.96, Time: 16.48)
#
# --- Edge 48 -> 13 ---
#   - Truck Info: (Distance: 90.84, Time: 90.84)
#   - Drone Info: (Distance: 90.84, Time: 45.42)
#
# --- Edge 48 -> 14 ---
#   - Truck Info: (Distance: 36.94, Time: 36.94)
#   - Drone Info: (Distance: 36.94, Time: 18.47)
#
# --- Edge 48 -> 15 ---
#   - Truck Info: (Distance: 20.87, Time: 20.87)
#   - Drone Info: (Distance: 20.87, Time: 10.43)
#
# --- Edge 48 -> 16 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 48 -> 17 ---
#   - Truck Info: (Distance: 17.20, Time: 17.20)
#   - Drone Info: (Distance: 17.20, Time: 8.60)
#
# --- Edge 48 -> 18 ---
#   - Truck Info: (Distance: 88.62, Time: 88.62)
#   - Drone Info: (Distance: 88.62, Time: 44.31)
#
# --- Edge 48 -> 19 ---
#   - Truck Info: (Distance: 89.94, Time: 89.94)
#   - Drone Info: (Distance: 89.94, Time: 44.97)
#
# --- Edge 48 -> 20 ---
#   - Truck Info: (Distance: 47.78, Time: 47.78)
#   - Drone Info: (Distance: 47.78, Time: 23.89)
#
# --- Edge 48 -> 21 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 48 -> 22 ---
#   - Truck Info: (Distance: 93.83, Time: 93.83)
#   - Drone Info: (Distance: 93.83, Time: 46.91)
#
# --- Edge 48 -> 23 ---
#   - Truck Info: (Distance: 40.07, Time: 40.07)
#   - Drone Info: (Distance: 40.07, Time: 20.03)
#
# --- Edge 48 -> 24 ---
#   - Truck Info: (Distance: 39.64, Time: 39.64)
#   - Drone Info: (Distance: 39.64, Time: 19.82)
#
# --- Edge 48 -> 25 ---
#   - Truck Info: (Distance: 94.27, Time: 94.27)
#   - Drone Info: (Distance: 94.27, Time: 47.14)
#
# --- Edge 48 -> 26 ---
#   - Truck Info: (Distance: 59.37, Time: 59.37)
#   - Drone Info: (Distance: 59.37, Time: 29.69)
#
# --- Edge 48 -> 27 ---
#   - Truck Info: (Distance: 30.00, Time: 30.00)
#   - Drone Info: (Distance: 30.00, Time: 15.00)
#
# --- Edge 48 -> 28 ---
#   - Truck Info: (Distance: 82.62, Time: 82.62)
#   - Drone Info: (Distance: 82.62, Time: 41.31)
#
# --- Edge 48 -> 29 ---
#   - Truck Info: (Distance: 20.51, Time: 20.51)
#   - Drone Info: (Distance: 20.51, Time: 10.25)
#
# --- Edge 48 -> 30 ---
#   - Truck Info: (Distance: 14.86, Time: 14.86)
#   - Drone Info: (Distance: 14.86, Time: 7.43)
#
# --- Edge 48 -> 31 ---
#   - Truck Info: (Distance: 31.32, Time: 31.32)
#   - Drone Info: (Distance: 31.32, Time: 15.66)
#
# --- Edge 48 -> 32 ---
#   - Truck Info: (Distance: 26.67, Time: 26.67)
#   - Drone Info: (Distance: 26.67, Time: 13.33)
#
# --- Edge 48 -> 33 ---
#   - Truck Info: (Distance: 41.65, Time: 41.65)
#   - Drone Info: (Distance: 41.65, Time: 20.83)
#
# --- Edge 48 -> 34 ---
#   - Truck Info: (Distance: 65.44, Time: 65.44)
#   - Drone Info: (Distance: 65.44, Time: 32.72)
#
# --- Edge 48 -> 35 ---
#   - Truck Info: (Distance: 65.58, Time: 65.58)
#   - Drone Info: (Distance: 65.58, Time: 32.79)
#
# --- Edge 48 -> 36 ---
#   - Truck Info: (Distance: 20.74, Time: 20.74)
#   - Drone Info: (Distance: 20.74, Time: 10.37)
#
# --- Edge 48 -> 37 ---
#   - Truck Info: (Distance: 51.20, Time: 51.20)
#   - Drone Info: (Distance: 51.20, Time: 25.60)
#
# --- Edge 48 -> 38 ---
#   - Truck Info: (Distance: 96.54, Time: 96.54)
#   - Drone Info: (Distance: 96.54, Time: 48.27)
#
# --- Edge 48 -> 39 ---
#   - Truck Info: (Distance: 32.55, Time: 32.55)
#   - Drone Info: (Distance: 32.55, Time: 16.28)
#
# --- Edge 48 -> 40 ---
#   - Truck Info: (Distance: 87.58, Time: 87.58)
#   - Drone Info: (Distance: 87.58, Time: 43.79)
#
# --- Edge 48 -> 41 ---
#   - Truck Info: (Distance: 41.73, Time: 41.73)
#   - Drone Info: (Distance: 41.73, Time: 20.87)
#
# --- Edge 48 -> 42 ---
#   - Truck Info: (Distance: 30.66, Time: 30.66)
#   - Drone Info: (Distance: 30.66, Time: 15.33)
#
# --- Edge 48 -> 43 ---
#   - Truck Info: (Distance: 32.72, Time: 32.72)
#   - Drone Info: (Distance: 32.72, Time: 16.36)
#
# --- Edge 48 -> 44 ---
#   - Truck Info: (Distance: 56.43, Time: 56.43)
#   - Drone Info: (Distance: 56.43, Time: 28.22)
#
# --- Edge 48 -> 45 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 48 -> 46 ---
#   - Truck Info: (Distance: 18.74, Time: 18.74)
#   - Drone Info: (Distance: 18.74, Time: 9.37)
#
# --- Edge 48 -> 47 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 48 -> 49 ---
#   - Truck Info: (Distance: 52.41, Time: 52.41)
#   - Drone Info: (Distance: 52.41, Time: 26.20)
#
# --- Edge 49 -> 0 ---
#   - Truck Info: (Distance: 7.70, Time: 7.70)
#   - Drone Info: (Distance: 7.70, Time: 3.85)
#
# --- Edge 49 -> 1 ---
#   - Truck Info: (Distance: 57.64, Time: 57.64)
#   - Drone Info: (Distance: 57.64, Time: 28.82)
#
# --- Edge 49 -> 2 ---
#   - Truck Info: (Distance: 45.03, Time: 45.03)
#   - Drone Info: (Distance: 45.03, Time: 22.51)
#
# --- Edge 49 -> 3 ---
#   - Truck Info: (Distance: 20.62, Time: 20.62)
#   - Drone Info: (Distance: 20.62, Time: 10.31)
#
# --- Edge 49 -> 4 ---
#   - Truck Info: (Distance: 38.98, Time: 38.98)
#   - Drone Info: (Distance: 38.98, Time: 19.49)
#
# --- Edge 49 -> 5 ---
#   - Truck Info: (Distance: 78.31, Time: 78.31)
#   - Drone Info: (Distance: 78.31, Time: 39.16)
#
# --- Edge 49 -> 6 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 49 -> 7 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 49 -> 8 ---
#   - Truck Info: (Distance: 51.82, Time: 51.82)
#   - Drone Info: (Distance: 51.82, Time: 25.91)
#
# --- Edge 49 -> 9 ---
#   - Truck Info: (Distance: 42.59, Time: 42.59)
#   - Drone Info: (Distance: 42.59, Time: 21.30)
#
# --- Edge 49 -> 10 ---
#   - Truck Info: (Distance: 59.02, Time: 59.02)
#   - Drone Info: (Distance: 59.02, Time: 29.51)
#
# --- Edge 49 -> 11 ---
#   - Truck Info: (Distance: 55.29, Time: 55.29)
#   - Drone Info: (Distance: 55.29, Time: 27.65)
#
# --- Edge 49 -> 12 ---
#   - Truck Info: (Distance: 97.27, Time: 97.27)
#   - Drone Info: (Distance: 97.27, Time: 48.64)
#
# --- Edge 49 -> 13 ---
#   - Truck Info: (Distance: 69.75, Time: 69.75)
#   - Drone Info: (Distance: 69.75, Time: 34.87)
#
# --- Edge 49 -> 14 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 49 -> 15 ---
#   - Truck Info: (Distance: 37.70, Time: 37.70)
#   - Drone Info: (Distance: 37.70, Time: 18.85)
#
# --- Edge 49 -> 16 ---
#   - Truck Info: (Distance: 64.34, Time: 64.34)
#   - Drone Info: (Distance: 64.34, Time: 32.17)
#
# --- Edge 49 -> 17 ---
#   - Truck Info: (Distance: 44.52, Time: 44.52)
#   - Drone Info: (Distance: 44.52, Time: 22.26)
#
# --- Edge 49 -> 18 ---
#   - Truck Info: (Distance: 95.00, Time: 95.00)
#   - Drone Info: (Distance: 95.00, Time: 47.50)
#
# --- Edge 49 -> 19 ---
#   - Truck Info: (Distance: 12.86, Time: 12.86)
#   - Drone Info: (Distance: 12.86, Time: 6.43)
#
# --- Edge 49 -> 20 ---
#   - Truck Info: (Distance: 90.14, Time: 90.14)
#   - Drone Info: (Distance: 90.14, Time: 45.07)
#
# --- Edge 49 -> 21 ---
#   - Truck Info: (Distance: 18.73, Time: 18.73)
#   - Drone Info: (Distance: 18.73, Time: 9.36)
#
# --- Edge 49 -> 22 ---
#   - Truck Info: (Distance: 29.28, Time: 29.28)
#   - Drone Info: (Distance: 29.28, Time: 14.64)
#
# --- Edge 49 -> 23 ---
#   - Truck Info: (Distance: 41.34, Time: 41.34)
#   - Drone Info: (Distance: 41.34, Time: 20.67)
#
# --- Edge 49 -> 24 ---
#   - Truck Info: (Distance: 90.62, Time: 90.62)
#   - Drone Info: (Distance: 90.62, Time: 45.31)
#
# --- Edge 49 -> 25 ---
#   - Truck Info: (Distance: 25.61, Time: 25.61)
#   - Drone Info: (Distance: 25.61, Time: 12.80)
#
# --- Edge 49 -> 26 ---
#   - Truck Info: (Distance: 33.43, Time: 33.43)
#   - Drone Info: (Distance: 33.43, Time: 16.72)
#
# --- Edge 49 -> 27 ---
#   - Truck Info: (Distance: 36.67, Time: 36.67)
#   - Drone Info: (Distance: 36.67, Time: 18.33)
#
# --- Edge 49 -> 28 ---
#   - Truck Info: (Distance: 97.59, Time: 97.59)
#   - Drone Info: (Distance: 97.59, Time: 48.79)
#
# --- Edge 49 -> 29 ---
#   - Truck Info: (Distance: 41.50, Time: 41.50)
#   - Drone Info: (Distance: 41.50, Time: 20.75)
#
# --- Edge 49 -> 30 ---
#   - Truck Info: (Distance: 93.26, Time: 93.26)
#   - Drone Info: (Distance: 93.26, Time: 46.63)
#
# --- Edge 49 -> 31 ---
#   - Truck Info: (Distance: 65.09, Time: 65.09)
#   - Drone Info: (Distance: 65.09, Time: 32.55)
#
# --- Edge 49 -> 32 ---
#   - Truck Info: (Distance: 28.90, Time: 28.90)
#   - Drone Info: (Distance: 28.90, Time: 14.45)
#
# --- Edge 49 -> 33 ---
#   - Truck Info: (Distance: 85.36, Time: 85.36)
#   - Drone Info: (Distance: 85.36, Time: 42.68)
#
# --- Edge 49 -> 34 ---
#   - Truck Info: (Distance: 13.47, Time: 13.47)
#   - Drone Info: (Distance: 13.47, Time: 6.74)
#
# --- Edge 49 -> 35 ---
#   - Truck Info: (Distance: 71.44, Time: 71.44)
#   - Drone Info: (Distance: 71.44, Time: 35.72)
#
# --- Edge 49 -> 36 ---
#   - Truck Info: (Distance: 63.25, Time: 63.25)
#   - Drone Info: (Distance: 63.25, Time: 31.62)
#
# --- Edge 49 -> 37 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 49 -> 38 ---
#   - Truck Info: (Distance: 94.57, Time: 94.57)
#   - Drone Info: (Distance: 94.57, Time: 47.28)
#
# --- Edge 49 -> 39 ---
#   - Truck Info: (Distance: 82.92, Time: 82.92)
#   - Drone Info: (Distance: 82.92, Time: 41.46)
#
# --- Edge 49 -> 40 ---
#   - Truck Info: (Distance: 81.77, Time: 81.77)
#   - Drone Info: (Distance: 81.77, Time: 40.89)
#
# --- Edge 49 -> 41 ---
#   - Truck Info: (Distance: 30.34, Time: 30.34)
#   - Drone Info: (Distance: 30.34, Time: 15.17)
#
# --- Edge 49 -> 42 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 49 -> 43 ---
#   - Truck Info: (Distance: 1000000.00, Time: 1000000.00)
#   - Drone Info: (Distance: 1000000.00, Time: 500000.00)
#
# --- Edge 49 -> 44 ---
#   - Truck Info: (Distance: 27.05, Time: 27.05)
#   - Drone Info: (Distance: 27.05, Time: 13.52)
#
# --- Edge 49 -> 45 ---
#   - Truck Info: (Distance: 81.35, Time: 81.35)
#   - Drone Info: (Distance: 81.35, Time: 40.68)
#
# --- Edge 49 -> 46 ---
#   - Truck Info: (Distance: 75.53, Time: 75.53)
#   - Drone Info: (Distance: 75.53, Time: 37.76)
#
# --- Edge 49 -> 47 ---
#   - Truck Info: (Distance: 90.15, Time: 90.15)
#   - Drone Info: (Distance: 90.15, Time: 45.07)
#
# --- Edge 49 -> 48 ---
#   - Truck Info: (Distance: 58.50, Time: 58.50)
#   - Drone Info: (Distance: 58.50, Time: 29.25)
#
# ============================================================
#            END OF MATRIX VISUALIZATION
# ============================================================
#
#
# --- STEP 2: Creating Initial Heuristic Solution ---
#   - ERROR: Initial demand exceeds truck capacity. Solution may be infeasible.
#
# --- STEP 3: Running ALNS Metaheuristic ---
# Initial Cost: 4004427.99
# Iteration 1/500 | New Best Cost: 4003953.27 (T=500.00)
# Iteration 2/500 | New Best Cost: 4003491.60 (T=497.50)
# Iteration 3/500 | New Best Cost: 4003347.38 (T=495.01)
# Iteration 4/500 | New Best Cost: 4003004.31 (T=492.54)
# Iteration 5/500 | New Best Cost: 4002954.62 (T=490.07)
# Iteration 6/500 | New Best Cost: 4002721.08 (T=487.62)
# Iteration 7/500 | New Best Cost: 2002744.14 (T=485.19)
# Iteration 8/500 | New Best Cost: 2001390.95 (T=482.76)
# Iteration 9/500 | New Best Cost: 2001384.06 (T=480.35)
# Iteration 10/500 | New Best Cost: 2001316.54 (T=477.94)
# Iteration 11/500 | New Best Cost: 2001065.99 (T=475.56)
# Iteration 13/500 | New Best Cost: 2000919.80 (T=470.81)
# Iteration 14/500 | New Best Cost: 947.86 (T=468.46)
# Iteration 15/500 | New Best Cost: 921.66 (T=466.12)
# Iteration 19/500 | New Best Cost: 781.50 (T=456.86)
# Iteration 21/500 | New Best Cost: 774.91 (T=452.31)
# Iteration 22/500 | New Best Cost: 762.18 (T=450.04)
# Iteration 24/500 | New Best Cost: 674.03 (T=445.55)
# Iteration 193/500 | New Best Cost: 660.88 (T=190.99)
# Iteration 195/500 | New Best Cost: 653.58 (T=189.08)
# Iteration 303/500 | New Best Cost: 629.57 (T=110.04)
#
# Finished. Final Best Cost: 629.57
#
# ========================================
#       FINAL SOLUTION SUMMARY
# ========================================
#
# 1. Truck Route:
#   - 0 -> 9 -> 29 -> 19 -> 16 -> 23 -> 34 -> 5 -> 17 -> 49 -> 21 -> 12 -> 27 -> 6 -> 41 -> 8 -> 43 -> 10 -> 20 -> 13 -> 28 -> 2 -> 35 -> 24 -> 33 -> 31 -> 25 -> 11 -> 38 -> 18 -> 7 -> 48 -> 3 -> 30 -> 14 -> 15 -> 37 -> 47 -> 26 -> 0
#
# 2. Hub-based Drone Deliveries:
#   - Hub 5 serves: [42, 36]
#   - Hub 16 serves: [39]
#   - Hub 21 serves: [40]
#   - Hub 34 serves: [1]
#   - Hub 44 serves: [32]
#   - Hub 46 serves: [4]
#
# 3. Truck-launched Drone Deliveries:
#   - None.
#
# 4. Unserved Requests:
#   - All requests served.

# %%
import math
import random
import numpy as np
import copy

# ==============================================================================
# SECTION 1: CÁC HẰNG SỐ VÀ THAM SỐ TOÀN CỤC
# ==============================================================================

# --- Chỉ số ma trận ---
NODE_TYPE, TRUCK_DIST, DRONE_DIST, TRUCK_TIME, DRONE_TIME = 0, 1, 2, 3, 4
# --- Loại Node ---
TYPE_POT, TYPE_HUB, TYPE_CUSTOMER = 1, 2, 3

# --- Tham số của Kịch bản (Scenario Parameters) ---
NUM_TRUCKS = 10
TRUCK_CAPACITY = 800
TRUCK_SPEED = 1.0

# --- Tham số Drone (Mô hình Giới hạn) ---
DRONES_PER_HUB = 4       # Mỗi trạm chỉ có thể phục vụ đồng thời 2 khách hàng
DRONES_PER_TRUCK = 2     # Mỗi xe tải chỉ có 1 drone để phóng đi
DRONE_CAPACITY = 50
DRONE_SPEED = 10.0
DRONE_MAX_RANGE_DIST = 150 # Tăng tầm bay cho bài toán lớn hơn
DRONE_LAUNCH_TIME = 1
DRONE_LAND_TIME = 1

# ==============================================================================
# SECTION 2: CÁC HÀM TẠO DỮ LIỆU
# ==============================================================================
# (Hàm create_random_adjacency_matrix và print_matrix_details giữ nguyên như cũ)
def create_random_adjacency_matrix(num_nodes, num_hubs, num_customers,
                                   max_dist=100, truck_speed=1.0, drone_speed=10.0):
    if 1 + num_hubs + num_customers != num_nodes:
        raise ValueError("Tổng số lượng các loại node không khớp với num_nodes.")
    A = np.zeros((num_nodes, num_nodes, 5))
    node_properties = []
    node_ids = list(range(1, num_nodes))
    random.shuffle(node_ids)
    A[0, 0, NODE_TYPE] = TYPE_POT
    node_properties.append({'id': 0, 'type': TYPE_POT, 'demand': 0})
    for i in range(num_hubs):
        hub_id = node_ids.pop()
        A[hub_id, hub_id, NODE_TYPE] = TYPE_HUB
        node_properties.append({'id': hub_id, 'type': TYPE_HUB, 'demand': 0})
    for cust_id in node_ids:
        A[cust_id, cust_id, NODE_TYPE] = TYPE_CUSTOMER
        demand = random.randint(5, 20)
        node_properties.append({'id': cust_id, 'type': TYPE_CUSTOMER, 'demand': demand})
    node_properties.sort(key=lambda x: x['id'])
    for i in range(num_nodes):
        for j in range(num_nodes):
            if i == j:
                continue

            # Tạo khoảng cách ngẫu nhiên
            # Không đối xứng, A[i,j]
            disconnect = random.random()
            dist = random.uniform(5, max_dist)
            if(disconnect>0.1):
              A[i, j, TRUCK_DIST] = dist
              A[i, j, DRONE_DIST] = dist
              A[i, j, TRUCK_TIME] = dist / truck_speed
              A[i, j, DRONE_TIME] = dist / drone_speed
            else:
              A[i, j, TRUCK_DIST] = 1000000
              A[i, j, DRONE_DIST] = 1000000
              A[i, j, TRUCK_TIME] = 1000000 / truck_speed
              A[i, j, DRONE_TIME] = 1000000 / drone_speed

    return A, node_properties

def print_matrix_details(A, node_properties):
    """
    In ra một báo cáo chi tiết, dễ đọc về nội dung của ma trận kề A.
    """
    num_nodes = A.shape[0]
    node_props_map = {node['id']: node for node in node_properties}

    # Anh xa tu ma so sang ten node
    node_type_map = {
        TYPE_POT: "Depot",
        TYPE_HUB: "Hub",
        TYPE_CUSTOMER: "Customer"
    }

    print("\n" + "="*60)
    print(f"      VISUALIZATION OF ADJACENCY MATRIX A ({num_nodes}x{num_nodes}x{A.shape[2]})")
    print("="*60)

    # duong cheo
    print("\n--- 1. Node Properties (Diagonal A[i,i,:]) ---")
    for i in range(num_nodes):
        node_type_code = A[i, i, NODE_TYPE]
        node_type_str = node_type_map.get(node_type_code, "Unknown")
        demand = node_props_map[i]['demand']
        print(f"Node {i}: Type = {node_type_str} (code={int(node_type_code)}), Demand = {demand}")

    # i khac j

    print("\n--- 2. Edge Properties (Off-diagonal A[i,j,:]) ---")
    for i in range(num_nodes):
        for j in range(num_nodes):
            if i == j:
                continue

            print(f"\n--- Edge {i} -> {j} ---")

            # matrix info
            truck_dist = A[i, j, TRUCK_DIST]
            truck_time = A[i, j, TRUCK_TIME]
            drone_dist = A[i, j, DRONE_DIST]
            drone_time = A[i, j, DRONE_TIME]

            print(f"  - Truck Info: (Distance: {truck_dist:.2f}, Time: {truck_time:.2f})")
            print(f"  - Drone Info: (Distance: {drone_dist:.2f}, Time: {drone_time:.2f})")

    print("\n" + "="*60)
    print("           END OF MATRIX VISUALIZATION")
    print("="*60 + "\n")

# HEURISTIC KHỞI TẠO CHO NHIỀU XE TẢI
class MultiVehicleMatrixSolver:
    def __init__(self, A, node_properties):
        self.A = A
        self.node_props = {node['id']: node for node in node_properties}
        self.num_nodes = A.shape[0]

    def initialize_solution(self):
        print("  - Building initial solution for MULTIPLE trucks...")
        hub_ids = [i for i in range(self.num_nodes) if self.A[i, i, NODE_TYPE] == TYPE_HUB]
        customer_ids = [i for i in range(self.num_nodes) if self.A[i, i, NODE_TYPE] == TYPE_CUSTOMER]

        hub_drone_assignments = {hid: [] for hid in hub_ids}
        hub_demands = {hid: 0 for hid in hub_ids}
        unserved_customers = list(customer_ids)

        # Giai đoạn 1: Gán drone từ trạm, có kiểm tra giới hạn
        for req_id in list(unserved_customers):
            # Sắp xếp các hub theo khoảng cách
            sorted_hubs = sorted(hub_ids, key=lambda hid: self.A[req_id, hid, DRONE_DIST])
            for hub_id in sorted_hubs:
                dist = self.A[req_id, hub_id, DRONE_DIST]
                # Kiểm tra cả tầm bay và số lượng drone có sẵn tại trạm
                if dist * 2 <= DRONE_MAX_RANGE_DIST and len(hub_drone_assignments[hub_id]) < DRONES_PER_HUB:
                    hub_drone_assignments[hub_id].append(req_id)
                    hub_demands[hub_id] += self.node_props[req_id]['demand']
                    unserved_customers.remove(req_id)
                    break # Chuyển sang khách hàng tiếp theo

        # Giai đoạn 2: Xây dựng tuần tự các tuyến xe tải
        points_for_truck_ids = unserved_customers + [hid for hid in hub_ids if hub_demands[hid] > 0]
        truck_routes = {f'truck_{i}': [] for i in range(NUM_TRUCKS)}

        for i in range(NUM_TRUCKS):
            truck_id = f'truck_{i}'
            current_loc = 0
            current_load = 0

            while points_for_truck_ids:
                # Tìm điểm gần nhất với vị trí hiện tại của xe tải
                best_point = min(points_for_truck_ids, key=lambda pid: self.A[current_loc, pid, TRUCK_DIST])
                demand_of_point = self.node_props[best_point]['demand'] if best_point in customer_ids else hub_demands[best_point]

                # Kiểm tra tải trọng
                if current_load + demand_of_point <= TRUCK_CAPACITY:
                    current_load += demand_of_point
                    truck_routes[truck_id].append(best_point)
                    current_loc = best_point
                    points_for_truck_ids.remove(best_point)
                else:
                    # Xe này đã đầy, chuyển sang xe tiếp theo
                    break

        # Những điểm còn lại sẽ không được phục vụ
        final_unserved = points_for_truck_ids

        return {
            'truck_routes': truck_routes,
            'hub_drone_assignments': hub_drone_assignments,
            'truck_launched_assignments': [],
            'unserved_requests': final_unserved
        }

# ==============================================================================
# SECTION 4: SIÊU THUẬT TOÁN ALNS (ĐÃ NÂNG CẤP)
# ==============================================================================
class ALNSSolver:
    # (Hàm __init__, _select_operator, _update_weights giữ nguyên)
    def __init__(self, A, node_properties, iterations=500, penalty_unserved=1000):
        self.A = A
        self.node_props = node_properties
        self.iterations = iterations
        self.penalty_unserved = penalty_unserved
        self.destroy_operators = [self.random_removal]
        self.repair_operators = [self.greedy_insertion]
        self.op_weights = {'destroy': [1] * len(self.destroy_operators), 'repair': [1] * len(self.repair_operators)}
        self.op_scores = {'destroy': [0]*len(self.destroy_operators), 'repair': [0]*len(self.repair_operators)}
        self.op_counts = {'destroy': [0]*len(self.destroy_operators), 'repair': [0]*len(self.repair_operators)}
        self.reaction_factor = 0.5
        self.start_temperature = 500
        self.end_temperature = 1
        self.cooling_rate = 0.995

    def solve(self, initial_solution):
        # (Hàm solve giữ nguyên, không cần thay đổi)
        current_solution = copy.deepcopy(initial_solution)
        best_solution = copy.deepcopy(initial_solution)
        current_cost = self.calculate_cost(current_solution)
        best_cost = current_cost
        temperature = self.start_temperature
        print(f"Initial Cost: {best_cost:.2f}")

        for i in range(self.iterations):
            destroy_op_idx, destroy_op = self._select_operator('destroy')
            repair_op_idx, repair_op = self._select_operator('repair')
            partial_solution, removed_requests = destroy_op(current_solution)
            new_solution = repair_op(partial_solution, removed_requests)
            new_cost = self.calculate_cost(new_solution)
            score = 0
            if new_cost < best_cost:
                best_solution = copy.deepcopy(new_solution)
                best_cost = new_cost
                current_solution = copy.deepcopy(new_solution)
                current_cost = new_cost
                score = 3
                print(f"Iteration {i+1}/{self.iterations} | New Best Cost: {best_cost:.2f} (T={temperature:.2f})")
            elif new_cost < current_cost:
                current_solution = copy.deepcopy(new_solution)
                current_cost = new_cost
                score = 2
            elif random.random() < math.exp((current_cost - new_cost) / temperature):
                current_solution = copy.deepcopy(new_solution)
                current_cost = new_cost
                score = 1
            self._update_weights(destroy_op_idx, repair_op_idx, score)
            temperature = max(self.end_temperature, temperature * self.cooling_rate)
        print(f"\nFinished. Final Best Cost: {best_cost:.2f}")
        return best_solution

    def calculate_cost(self, solution):
        """Đã cập nhật để tính chi phí cho nhiều xe tải."""
        if not solution: return float('inf')
        total_dist = 0
        # Chi phí của tất cả các xe tải
        for truck_id, route in solution['truck_routes'].items():
            route_with_depot = [0] + route + [0]
            for i in range(len(route_with_depot) - 1):
                total_dist += self.A[route_with_depot[i], route_with_depot[i+1], TRUCK_DIST]

        # (Phần còn lại giữ nguyên)
        for hub_id, reqs in solution['hub_drone_assignments'].items():
            for req_id in reqs:
                total_dist += 2 * self.A[hub_id, req_id, DRONE_DIST]
        for assign in solution['truck_launched_assignments']:
            total_dist += self.A[assign['launch'], assign['req_id'], DRONE_DIST] + self.A[assign['req_id'], assign['rendezvous'], DRONE_DIST]
        penalty = len(solution['unserved_requests']) * self.penalty_unserved
        return total_dist + penalty

    def random_removal(self, solution, percentage=0.3):
        """Đã cập nhật để làm việc với nhiều xe tải."""
        sol = copy.deepcopy(solution)
        served_customers = set()

        for route in sol['truck_routes'].values():
            for node in route:
                if self.A[node, node, NODE_TYPE] == TYPE_CUSTOMER:
                    served_customers.add(node)
        for reqs in sol['hub_drone_assignments'].values():
            served_customers.update(reqs)
        for assign in sol['truck_launched_assignments']:
            served_customers.add(assign['req_id'])

        if not served_customers: return sol, []

        num_to_remove = max(1, int(len(served_customers) * percentage))
        requests_to_remove = random.sample(list(served_customers), num_to_remove)

        for truck_id in sol['truck_routes']:
            sol['truck_routes'][truck_id] = [r for r in sol['truck_routes'][truck_id] if r not in requests_to_remove]
        for hub_id in sol['hub_drone_assignments']:
            sol['hub_drone_assignments'][hub_id] = [r for r in sol['hub_drone_assignments'][hub_id] if r not in requests_to_remove]
        sol['truck_launched_assignments'] = [a for a in sol['truck_launched_assignments'] if a['req_id'] not in requests_to_remove]

        current_unserved = set(sol['unserved_requests'])
        current_unserved.update(requests_to_remove)
        sol['unserved_requests'] = list(current_unserved)

        return sol, requests_to_remove

    def greedy_insertion(self, partial_solution, requests_to_insert):
        """Đã cập nhật để chèn vào nhiều xe và kiểm tra giới hạn drone."""
        sol = copy.deepcopy(partial_solution)

        for req_id in requests_to_insert:
            best_move = {'cost': float('inf'), 'solution': None}

            # 1. Thử chèn vào MỌI tuyến xe tải ở MỌI vị trí
            for truck_id, route in sol['truck_routes'].items():
                for i in range(len(route) + 1):
                    temp_sol = copy.deepcopy(sol)
                    temp_sol['truck_routes'][truck_id].insert(i, req_id)
                    if req_id in temp_sol['unserved_requests']:
                        temp_sol['unserved_requests'].remove(req_id)
                    cost = self.calculate_cost(temp_sol)
                    if cost < best_move['cost']:
                        best_move['cost'], best_move['solution'] = cost, temp_sol

            # 2. Thử gán cho MỌI trạm (có kiểm tra giới hạn drone)
            for hub_id in sol['hub_drone_assignments']:
                if len(sol['hub_drone_assignments'][hub_id]) < DRONES_PER_HUB:
                    temp_sol = copy.deepcopy(sol)
                    temp_sol['hub_drone_assignments'][hub_id].append(req_id)
                    if req_id in temp_sol['unserved_requests']:
                        temp_sol['unserved_requests'].remove(req_id)
                    cost = self.calculate_cost(temp_sol)
                    if cost < best_move['cost']:
                        best_move['cost'], best_move['solution'] = cost, temp_sol

            # (Logic cho truck-launched drone có thể thêm ở đây, có kiểm tra DRONES_PER_TRUCK)

            if best_move['solution']:
                sol = best_move['solution']

        return sol

    def _select_operator(self, op_type):
        # (Hàm này giữ nguyên)
        weights = self.op_weights[op_type]
        rand_val = random.uniform(0, sum(weights))
        cumulative_weight = 0
        for i, weight in enumerate(weights):
            cumulative_weight += weight
            if rand_val <= cumulative_weight:
                return (i, self.destroy_operators[i]) if op_type == 'destroy' else (i, self.repair_operators[i])

    def _update_weights(self, destroy_idx, repair_idx, score):
        # (Hàm này giữ nguyên)
        if score > 0:
            self.op_scores['destroy'][destroy_idx] += score
            self.op_scores['repair'][repair_idx] += score
            self.op_counts['destroy'][destroy_idx] += 1
            self.op_counts['repair'][repair_idx] += 1
            if sum(self.op_counts['destroy']) % 50 == 0:
                for op_type in ['destroy', 'repair']:
                    for i in range(len(self.op_weights[op_type])):
                        count = self.op_counts[op_type][i]
                        avg_score = self.op_scores[op_type][i] / count if count > 0 else 0
                        self.op_weights[op_type][i] = (1 - self.reaction_factor) * self.op_weights[op_type][i] + self.reaction_factor * avg_score

# ==============================================================================
# SECTION 5: CHƯƠNG TRÌNH CHÍNH
# ==============================================================================
if __name__ == "__main__":
    print("--- STEP 1: Creating RANDOM Adjacency Matrix A ---")
    NUM_TOTAL_NODES, NUM_HUBS, NUM_CUSTOMERS = 200, 5, 194

    A, RANDOM_NODE_PROPERTIES = create_random_adjacency_matrix(
        num_nodes=NUM_TOTAL_NODES, num_hubs=NUM_HUBS, num_customers=NUM_CUSTOMERS,
        max_dist=200
    )

    print("\n--- STEP 2: Creating Initial Heuristic Solution for Multiple Trucks ---")
    initial_solver = MultiVehicleMatrixSolver(A, RANDOM_NODE_PROPERTIES)
    initial_solution = initial_solver.initialize_solution()

    if initial_solution:
        print("\n--- STEP 3: Running ALNS Metaheuristic ---")
        alns_solver = ALNSSolver(A, RANDOM_NODE_PROPERTIES, iterations=50, penalty_unserved=5000)
        final_solution = alns_solver.solve(initial_solution)

        print("\n" + "="*40)
        print("      FINAL SOLUTION SUMMARY")
        print("="*40)
        print("\n1. Truck Routes:")
        for truck_id, route in final_solution['truck_routes'].items():
            if route:
                path_str = ' -> '.join(map(str, route))
                print(f"  - {truck_id}: 0 -> {path_str} -> 0")
            else:
                print(f"  - {truck_id}: Not used.")

        print("\n2. Hub-based Drone Deliveries:")
        for hub_id, reqs in final_solution['hub_drone_assignments'].items():
            if reqs:
                print(f"  - Hub {hub_id} serves: {reqs} ({len(reqs)}/{DRONES_PER_HUB} slots used)")

        # ... (phần in kết quả còn lại) ...
        print("\n4. Unserved Requests:")
        if final_solution['unserved_requests']:
            print(f"  - {final_solution['unserved_requests']}")
        else:
            print("  - All requests served.")
# Out:
# --- STEP 1: Creating RANDOM Adjacency Matrix A ---
#
# --- STEP 2: Creating Initial Heuristic Solution for Multiple Trucks ---
#   - Building initial solution for MULTIPLE trucks...
#
# --- STEP 3: Running ALNS Metaheuristic ---
# Initial Cost: 6005213.10
# Iteration 1/50 | New Best Cost: 6004934.92 (T=500.00)
# Iteration 2/50 | New Best Cost: 4004765.67 (T=497.50)
# Iteration 3/50 | New Best Cost: 2004773.56 (T=495.01)
# Iteration 4/50 | New Best Cost: 2004731.30 (T=492.54)
# Iteration 5/50 | New Best Cost: 2004667.73 (T=490.07)
# Iteration 7/50 | New Best Cost: 2004494.20 (T=485.19)
# Iteration 8/50 | New Best Cost: 4097.87 (T=482.76)
# Iteration 36/50 | New Best Cost: 4066.74 (T=419.54)
# Iteration 38/50 | New Best Cost: 4037.17 (T=415.36)
# Iteration 43/50 | New Best Cost: 4007.52 (T=405.08)
# Iteration 46/50 | New Best Cost: 3842.63 (T=399.03)
#
# Finished. Final Best Cost: 3842.63
#
# ========================================
#       FINAL SOLUTION SUMMARY
# ========================================
#
# 1. Truck Routes:
#   - truck_0: 0 -> 197 -> 11 -> 79 -> 78 -> 20 -> 199 -> 191 -> 127 -> 90 -> 153 -> 104 -> 122 -> 52 -> 81 -> 194 -> 85 -> 21 -> 50 -> 46 -> 170 -> 103 -> 24 -> 141 -> 54 -> 60 -> 94 -> 71 -> 23 -> 116 -> 180 -> 146 -> 48 -> 19 -> 160 -> 39 -> 159 -> 35 -> 115 -> 99 -> 185 -> 91 -> 34 -> 135 -> 0
#   - truck_1: 0 -> 47 -> 108 -> 126 -> 86 -> 64 -> 131 -> 118 -> 62 -> 75 -> 17 -> 163 -> 142 -> 114 -> 136 -> 4 -> 128 -> 179 -> 89 -> 15 -> 183 -> 26 -> 8 -> 82 -> 119 -> 189 -> 25 -> 181 -> 41 -> 184 -> 176 -> 49 -> 42 -> 63 -> 43 -> 120 -> 93 -> 106 -> 164 -> 140 -> 66 -> 151 -> 107 -> 83 -> 9 -> 138 -> 13 -> 182 -> 165 -> 190 -> 92 -> 1 -> 188 -> 147 -> 33 -> 177 -> 3 -> 44 -> 37 -> 158 -> 6 -> 45 -> 58 -> 36 -> 144 -> 98 -> 171 -> 168 -> 61 -> 22 -> 29 -> 0
#   - truck_2: 0 -> 87 -> 132 -> 70 -> 28 -> 193 -> 100 -> 195 -> 88 -> 174 -> 187 -> 196 -> 57 -> 139 -> 14 -> 117 -> 31 -> 69 -> 157 -> 38 -> 121 -> 65 -> 74 -> 5 -> 129 -> 145 -> 137 -> 130 -> 175 -> 172 -> 166 -> 2 -> 55 -> 111 -> 154 -> 80 -> 143 -> 186 -> 123 -> 16 -> 148 -> 156 -> 112 -> 53 -> 77 -> 149 -> 59 -> 162 -> 105 -> 72 -> 150 -> 161 -> 51 -> 18 -> 110 -> 124 -> 178 -> 113 -> 27 -> 192 -> 7 -> 73 -> 68 -> 12 -> 134 -> 198 -> 96 -> 32 -> 102 -> 30 -> 76 -> 95 -> 133 -> 152 -> 56 -> 155 -> 84 -> 167 -> 97 -> 10 -> 109 -> 40 -> 67 -> 169 -> 173 -> 0
#   - truck_3: Not used.
#   - truck_4: Not used.
#   - truck_5: Not used.
#   - truck_6: Not used.
#   - truck_7: Not used.
#   - truck_8: Not used.
#   - truck_9: Not used.
#
# 2. Hub-based Drone Deliveries:
#   - Hub 158 serves: [101] (1/4 slots used)
#   - Hub 188 serves: [125] (1/4 slots used)
#
# 4. Unserved Requests:
#   - All requests served.

# %%
import math
import random
import numpy as np
import copy

# ==============================================================================
# SECTION 1: CÁC HẰNG SỐ VÀ THAM SỐ TOÀN CỤC
# ==============================================================================

# --- Chỉ số ma trận & Loại Node ---
NODE_TYPE, TRUCK_DIST, DRONE_DIST, TRUCK_TIME, DRONE_TIME = 0, 1, 2, 3, 4
TYPE_POT, TYPE_HUB, TYPE_CUSTOMER = 1, 2, 3

# --- Tham số của Kịch bản (Scenario Parameters) ---
NUM_TRUCKS = 10
TRUCK_CAPACITY = 100
TRUCK_SPEED = 1.0

# --- Tham số Drone (Mô hình Giới hạn) ---
DRONES_PER_HUB = 2
DRONES_PER_TRUCK = 1
DRONE_CAPACITY = 1000
DRONE_SPEED = 100.0
DRONE_MAX_RANGE_DIST = 150
SERVICE_TIME = 5 # Thời gian dỡ hàng/phục vụ tại mỗi điểm dừng

# ==============================================================================
# SECTION 2: CÁC HÀM TẠO DỮ LIỆU
# ==============================================================================

def create_random_adjacency_matrix(num_nodes, num_hubs, num_customers,
                                   max_dist=100, truck_speed=1.0, drone_speed=2.0):
    if 1 + num_hubs + num_customers != num_nodes:
        raise ValueError("Tổng số lượng các loại node không khớp với num_nodes.")

    A = np.zeros((num_nodes, num_nodes, 5))
    node_properties = []

    node_ids = list(range(1, num_nodes))
    random.shuffle(node_ids)

    A[0, 0, NODE_TYPE] = TYPE_POT
    node_properties.append({'id': 0, 'type': TYPE_POT, 'demand': 0, 'ready_time': 0, 'due_date': 2000})

    for i in range(num_hubs):
        hub_id = node_ids.pop()
        A[hub_id, hub_id, NODE_TYPE] = TYPE_HUB
        node_properties.append({'id': hub_id, 'type': TYPE_HUB, 'demand': 0, 'ready_time': 0, 'due_date': float('inf')})

    for cust_id in node_ids:
        A[cust_id, cust_id, NODE_TYPE] = TYPE_CUSTOMER
        demand = random.randint(5, 15)
        ready_time = random.randint(0, 8000)
        due_date = ready_time + random.randint(100, 3000)
        node_properties.append({'id': cust_id, 'type': TYPE_CUSTOMER, 'demand': demand,
                                'ready_time': ready_time, 'due_date': due_date})

    node_properties.sort(key=lambda x: x['id'])

    for i in range(num_nodes):
        for j in range(num_nodes):
            if i == j: continue
            dist = random.uniform(10, max_dist)
            A[i, j, TRUCK_DIST], A[i, j, DRONE_DIST] = dist, dist
            A[i, j, TRUCK_TIME], A[i, j, DRONE_TIME] = dist / truck_speed, dist / drone_speed

    return A, node_properties

# ==============================================================================
# SECTION 3: HEURISTIC KHỞI TẠO
# ==============================================================================
class MultiVehicleMatrixSolver:
    def __init__(self, A, node_properties):
        self.A = A
        self.node_props = {node['id']: node for node in node_properties}
        self.num_nodes = A.shape[0]

    def initialize_solution(self):
        # ... (logic heuristic đơn giản, ALNS sẽ làm phần việc chính)
        customer_ids = [i for i in range(self.num_nodes) if self.A[i, i, NODE_TYPE] == TYPE_CUSTOMER]
        truck_routes = {f'truck_{i}': [] for i in range(NUM_TRUCKS)}

        # Phân bổ khách hàng đều cho các xe tải
        for i, cust_id in enumerate(customer_ids):
            truck_index = i % NUM_TRUCKS
            truck_routes[f'truck_{truck_index}'].append(cust_id)

        return {
            'truck_routes': truck_routes, 'hub_drone_assignments': {},
            'truck_launched_assignments': [], 'unserved_requests': []
        }

# ==============================================================================
# SECTION 4: SIÊU THUẬT TOÁN ALNS (PHIÊN BẢN HOÀN CHỈNH)
# ==============================================================================
class ALNSSolver:
    def __init__(self, A, node_properties, iterations=1000, penalty_unserved=5000):
        self.A = A
        self.node_props = node_properties
        self.iterations = iterations
        self.penalty_unserved = penalty_unserved
        self.destroy_operators = [self.random_removal] # Có thể thêm Shaw, etc.
        self.repair_operators = [self.greedy_insertion] # Có thể thêm Regret, etc.
        self.op_weights = {'destroy': [1], 'repair': [1]}
        self.op_scores = {'destroy': [0], 'repair': [0]}
        self.op_counts = {'destroy': [0], 'repair': [0]}
        self.reaction_factor = 0.5
        self.start_temperature = 100
        self.end_temperature = 0.1
        self.cooling_rate = 0.999

    # --- HÀM ĐÁNH GIÁ VÀ TÍNH CHI PHÍ TOÀN DIỆN ---
    def calculate_cost(self, solution):
        total_cost = 0

        # 1. Chi phí phạt cho khách hàng không được phục vụ
        total_cost += len(solution['unserved_requests']) * self.penalty_unserved

        # 2. Đánh giá các tuyến xe tải và các nhiệm vụ drone liên quan
        all_hub_assignments = solution['hub_drone_assignments']
        all_truck_drone_assignments = solution['truck_launched_assignments']

        for truck_id, route in solution['truck_routes'].items():
            current_time = 0.0
            current_load = 0.0
            last_node = 0

            # Kiểm tra tải trọng trước
            route_demand = sum(self.node_props[node_id]['demand'] for node_id in route)
            if route_demand > TRUCK_CAPACITY: return float('inf')

            route_with_depot = [0] + route + [0]

            for i in range(len(route_with_depot) - 1):
                start_node = route_with_depot[i]
                end_node = route_with_depot[i+1]

                # Thời gian khởi hành của xe tải từ start_node
                departure_time_from_start = current_time

                # Chi phí di chuyển của xe tải trên chặng này
                truck_travel_time = self.A[start_node, end_node, TRUCK_TIME]
                truck_travel_dist = self.A[start_node, end_node, TRUCK_DIST]
                total_cost += truck_travel_dist

                # --- KIỂM TRA DRONE TỪ XE TẢI TRÊN CHẶNG NÀY ---
                missions_on_this_leg = [m for m in all_truck_drone_assignments
                                        if m.get('truck_id') == truck_id and
                                           m.get('launch') == start_node and
                                           m.get('rendezvous') == end_node]

                if len(missions_on_this_leg) > DRONES_PER_TRUCK: return float('inf')

                for mission in missions_on_this_leg:
                    cust_id = mission['req_id']
                    drone_flight_time = self.A[start_node, cust_id, DRONE_TIME] + self.A[cust_id, end_node, DRONE_TIME]
                    drone_total_time = drone_flight_time # Giả sử launch/land time = 0 để đơn giản

                    if drone_total_time > truck_travel_time: return float('inf') # Lỗi đồng bộ hóa

                    drone_arrival_at_cust = departure_time_from_start + self.A[start_node, cust_id, DRONE_TIME]
                    cust_info = self.node_props[cust_id]

                    drone_service_start = max(drone_arrival_at_cust, cust_info['ready_time'])
                    if drone_service_start > cust_info['due_date']: return float('inf') # Lỗi time window

                    total_cost += self.A[start_node, cust_id, DRONE_DIST] + self.A[cust_id, end_node, DRONE_DIST]

                # Cập nhật thời gian của xe tải khi đến end_node
                current_time += truck_travel_time
                end_node_info = self.node_props[end_node]
                current_time = max(current_time, end_node_info['ready_time']) # Chờ đợi

                if current_time > end_node_info['due_date']: return float('inf') # Lỗi time window xe tải

                current_time += SERVICE_TIME # Thời gian phục vụ của xe tải

                # --- KIỂM TRA DRONE TỪ TRẠM (NẾU end_node LÀ TRẠM) ---
                if end_node_info['type'] == TYPE_HUB:
                    assigned_customers = all_hub_assignments.get(end_node, [])
                    if len(assigned_customers) > DRONES_PER_HUB: return float('inf')

                    # Thời gian drone có thể bắt đầu bay từ trạm
                    drone_departure_from_hub = current_time

                    for cust_id in assigned_customers:
                        drone_arrival_at_cust = drone_departure_from_hub + self.A[end_node, cust_id, DRONE_TIME]
                        cust_info = self.node_props[cust_id]

                        drone_service_start = max(drone_arrival_at_cust, cust_info['ready_time'])
                        if drone_service_start > cust_info['due_date']: return float('inf')

                        total_cost += 2 * self.A[end_node, cust_id, DRONE_DIST]

                last_node = end_node

        return total_cost

    def solve(self, initial_solution):
        # ... (logic vòng lặp chính không đổi)
        current_solution = copy.deepcopy(initial_solution)
        best_solution = copy.deepcopy(initial_solution)
        current_cost = self.calculate_cost(current_solution)
        best_cost = current_cost
        temperature = self.start_temperature
        print(f"Initial Cost: {best_cost:.2f} (May be infeasible)")

        for i in range(self.iterations):
            destroy_op_idx, destroy_op = self._select_operator('destroy')
            repair_op_idx, repair_op = self._select_operator('repair')
            partial_solution, removed_requests = destroy_op(current_solution)
            new_solution = repair_op(partial_solution, removed_requests)
            new_cost = self.calculate_cost(new_solution)
            score = 0
            if new_cost < best_cost:
                best_solution, best_cost = copy.deepcopy(new_solution), new_cost
                current_solution, current_cost = copy.deepcopy(new_solution), new_cost
                score = 3
                print(f"Iteration {i+1}/{self.iterations} | New Best Cost: {best_cost:.2f} (T={temperature:.2f})")
            elif new_cost < current_cost:
                current_solution, current_cost = copy.deepcopy(new_solution), new_cost
                score = 2
            elif random.random() < math.exp((current_cost - new_cost) / temperature):
                current_solution, current_cost = copy.deepcopy(new_solution), new_cost
                score = 1
            self._update_weights(destroy_op_idx, repair_op_idx, score)
            temperature = max(self.end_temperature, temperature * self.cooling_rate)
        print(f"\nFinished. Final Best Cost: {best_cost:.2f}")
        return best_solution

    def random_removal(self, solution, percentage=0.3):
        # ... (logic không đổi)
        sol = copy.deepcopy(solution)
        served_customers = set()
        for route in sol['truck_routes'].values():
            for node in route:
                if self.A[node, node, NODE_TYPE] == TYPE_CUSTOMER:
                    served_customers.add(node)
        for reqs in sol['hub_drone_assignments'].values(): served_customers.update(reqs)
        for assign in sol['truck_launched_assignments']: served_customers.add(assign['req_id'])
        if not served_customers: return sol, []
        num_to_remove = max(1, int(len(served_customers) * percentage))
        requests_to_remove = random.sample(list(served_customers), num_to_remove)
        for truck_id in sol['truck_routes']:
            sol['truck_routes'][truck_id] = [r for r in sol['truck_routes'][truck_id] if r not in requests_to_remove]
        for hub_id in sol['hub_drone_assignments']:
            sol['hub_drone_assignments'][hub_id] = [r for r in sol['hub_drone_assignments'][hub_id] if r not in requests_to_remove]
        sol['truck_launched_assignments'] = [a for a in sol['truck_launched_assignments'] if a['req_id'] not in requests_to_remove]
        current_unserved = set(sol['unserved_requests'])
        current_unserved.update(requests_to_remove)
        sol['unserved_requests'] = list(current_unserved)
        return sol, requests_to_remove

    def greedy_insertion(self, partial_solution, requests_to_insert):
        sol = copy.deepcopy(partial_solution)
        for req_id in requests_to_insert:
            best_move = {'cost': float('inf'), 'solution': None}
            # 1. Thử chèn vào tuyến xe tải
            for truck_id, route in sol['truck_routes'].items():
                for i in range(len(route) + 1):
                    temp_sol = copy.deepcopy(sol)
                    temp_sol['truck_routes'][truck_id].insert(i, req_id)
                    temp_sol['unserved_requests'].remove(req_id)
                    cost = self.calculate_cost(temp_sol)
                    if cost < best_move['cost']: best_move['cost'], best_move['solution'] = cost, temp_sol

            # 2. Thử gán cho trạm
            for hub_id in sol['hub_drone_assignments']:
                temp_sol = copy.deepcopy(sol)
                temp_sol['hub_drone_assignments'][hub_id].append(req_id)
                temp_sol['unserved_requests'].remove(req_id)
                cost = self.calculate_cost(temp_sol)
                if cost < best_move['cost']: best_move['cost'], best_move['solution'] = cost, temp_sol

            # 3. Thử gán cho drone từ xe tải
            for truck_id, route in sol['truck_routes'].items():
                route_with_depot = [0] + route + [0]
                for i in range(len(route_with_depot) - 1):
                    temp_sol = copy.deepcopy(sol)
                    mission = {'req_id': req_id, 'truck_id': truck_id,
                               'launch': route_with_depot[i], 'rendezvous': route_with_depot[i+1]}
                    temp_sol['truck_launched_assignments'].append(mission)
                    temp_sol['unserved_requests'].remove(req_id)
                    cost = self.calculate_cost(temp_sol)
                    if cost < best_move['cost']: best_move['cost'], best_move['solution'] = cost, temp_sol

            if best_move['solution']: sol = best_move['solution']
        return sol

    def _select_operator(self, op_type):
        # ... (logic không đổi)
        weights = self.op_weights[op_type]
        rand_val = random.uniform(0, sum(weights))
        cumulative_weight = 0
        for i, weight in enumerate(weights):
            cumulative_weight += weight
            if rand_val <= cumulative_weight:
                return (i, self.destroy_operators[i]) if op_type == 'destroy' else (i, self.repair_operators[i])

    def _update_weights(self, destroy_idx, repair_idx, score):
        # ... (logic không đổi)
        if score > 0:
            self.op_scores['destroy'][destroy_idx] += score
            self.op_scores['repair'][repair_idx] += score
            self.op_counts['destroy'][destroy_idx] += 1
            self.op_counts['repair'][repair_idx] += 1
            if sum(self.op_counts['destroy']) % 50 == 0:
                for op_type in ['destroy', 'repair']:
                    for i in range(len(self.op_weights[op_type])):
                        count = self.op_counts[op_type][i]
                        avg_score = self.op_scores[op_type][i] / count if count > 0 else 0
                        self.op_weights[op_type][i] = (1 - self.reaction_factor) * self.op_weights[op_type][i] + self.reaction_factor * avg_score

# ==============================================================================
# SECTION 5: CHƯƠNG TRÌNH CHÍNH
# ==============================================================================
if __name__ == "__main__":
    print("--- STEP 1: Creating RANDOM Adjacency Matrix with Time Windows ---")
    NUM_TOTAL_NODES, NUM_HUBS, NUM_CUSTOMERS = 30, 5, 24

    A, RANDOM_NODE_PROPERTIES = create_random_adjacency_matrix(
        num_nodes=NUM_TOTAL_NODES, num_hubs=NUM_HUBS, num_customers=NUM_CUSTOMERS, max_dist=200
    )

    print("\n--- STEP 2: Creating Initial Solution (may be infeasible) ---")
    initial_solver = MultiVehicleMatrixSolver(A, RANDOM_NODE_PROPERTIES)
    initial_solution = initial_solver.initialize_solution()

    if initial_solution:
        print("\n--- STEP 3: Running ALNS Metaheuristic (handling all constraints) ---")
        alns_solver = ALNSSolver(A, RANDOM_NODE_PROPERTIES, iterations=500, penalty_unserved=10000)
        final_solution = alns_solver.solve(initial_solution)

        print("\n" + "="*50)
        print(" " * 15 + "FINAL SOLUTION SUMMARY")
        print("="*50)
        print("\n1. Truck Routes:")
        for truck_id, route in final_solution['truck_routes'].items():
            if route: print(f"  - {truck_id}: 0 -> {' -> '.join(map(str, route))} -> 0")
            else: print(f"  - {truck_id}: Not used.")

        print("\n2. Hub-based Drone Deliveries:")
        for hub_id, reqs in final_solution['hub_drone_assignments'].items():
            if reqs: print(f"  - Hub {hub_id} serves: {reqs} ({len(reqs)}/{DRONES_PER_HUB} slots used)")

        print("\n3. Truck-launched Drone Deliveries:")
        if final_solution['truck_launched_assignments']:
            for assign in final_solution['truck_launched_assignments']:
                print(f"  - Cust {assign['req_id']} from {assign['truck_id']} on segment {assign['launch']}->{assign['rendezvous']}")
        else: print("  - None.")

        print("\n4. Unserved Requests:")
        if final_solution['unserved_requests']: print(f"  - {final_solution['unserved_requests']}")
        else: print("  - All requests served.")
        print("="*50)
# Out:
# --- STEP 1: Creating RANDOM Adjacency Matrix with Time Windows ---
#
# --- STEP 2: Creating Initial Solution (may be infeasible) ---
#
# --- STEP 3: Running ALNS Metaheuristic (handling all constraints) ---
# Initial Cost: inf (May be infeasible)
#
# Finished. Final Best Cost: inf
#
# ==================================================
#                FINAL SOLUTION SUMMARY
# ==================================================
#
# 1. Truck Routes:
#   - truck_0: 0 -> 3 -> 14 -> 26 -> 0
#   - truck_1: 0 -> 4 -> 15 -> 27 -> 0
#   - truck_2: 0 -> 5 -> 17 -> 28 -> 0
#   - truck_3: 0 -> 6 -> 18 -> 29 -> 0
#   - truck_4: 0 -> 7 -> 19 -> 0
#   - truck_5: 0 -> 8 -> 20 -> 0
#   - truck_6: 0 -> 10 -> 21 -> 0
#   - truck_7: 0 -> 11 -> 23 -> 0
#   - truck_8: 0 -> 12 -> 24 -> 0
#   - truck_9: 0 -> 13 -> 25 -> 0
#
# 2. Hub-based Drone Deliveries:
#
# 3. Truck-launched Drone Deliveries:
#   - None.
#
# 4. Unserved Requests:
#   - All requests served.
# ==================================================
